# %% [markdown]
# # Forced Alignment of Phonemes
# Author: Oscar Friedman

# %% [markdown]
# This notebook performs forced alignment of English phonemes. Forced alignment requires an input speech or singing audio file and corresponding text transcript, and outputs start and end timestamps corresponding to each phoneme.
#
# We will compare 3 approaches.

# %%
# first time only:
# !pip install -r requirements.txt

import torch
import torchaudio
from torchaudio.datasets import CMUDict
import torchaudio.transforms as T
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

from dataclasses import dataclass
import IPython
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams["figure.figsize"] = [16.0, 4.8]
import json
import re
import os
import string
import copy
import IPython
import tgt

from transformers import Wav2Vec2CTCTokenizer
from transformers import Wav2Vec2FeatureExtractor
from transformers import Wav2Vec2Processor
from transformers import Wav2Vec2ForCTC

# %%
def load_audio(audio_file):
    root, _ = os.path.splitext(audio_file)
    output_file = f"{root}.wav"
    os.system(f'ffmpeg -y -i {audio_file} -acodec pcm_s16le -ac 1 -ar 16000 {output_file}') # Convert test file to correct format for wav2vec2 (16khz mono wav 16-bit)
    audio_file = output_file
    waveform, sample_rate = torchaudio.load(audio_file)
    return waveform, sample_rate

def load_transcript(transcript_file):
    with open(transcript_file, "r") as file:
        transcript = file.read()
    return transcript

def format_transcript(transcript): # Remove punctuation, convert each letter to uppercase and join words with '|'
    import string
    translator = str.maketrans('', '', string.punctuation)
    cleaned_string = transcript.translate(translator)
    words = cleaned_string.split()   
    result_string = '|'.join(word.upper() for word in words)
    return result_string

def save_phonemes_JSON(phonemes, output_file):
    phoneme_segments = []
    for phoneme in phonemes:
        phoneme_segments.append({'phoneme': phoneme.label, 'start': phoneme.start, 'end': phoneme.end})
    with open(output_file, 'w') as outfile:
        json.dump(phoneme_segments, outfile)

def display_segment(segments,i, waveform, sample_rate=16000):
    phoneme = segments[i]
    x0 = int(phoneme.start * sample_rate)
    x1 = int(phoneme.end * sample_rate)
    print(f"{phoneme.label} ({phoneme.score:.2f}): {phoneme.start:.3f} - {phoneme.end:.3f} sec")
    segment = waveform[0][x0:x1]
    return IPython.display.display(IPython.display.Audio(segment, rate=sample_rate))

# %%
audio_file = r'C:\Users\oscar\Documents\470\JS_2023\Phoneme_Recognition\input\assessment_9.mp3'
audio_file = audio_file.replace('\\', '/')
waveform, sample_rate = load_audio(audio_file)
IPython.display.display(IPython.display.Audio(waveform, rate=sample_rate))

transcript_file = r'C:\Users\oscar\Documents\470\JS_2023\Phoneme_Recognition\input\assessment_9.txt'
transcript_file = transcript_file.replace('\\', '/')
transcript = load_transcript(transcript_file)
transcript = format_transcript(transcript)
print(f"Transcript: {transcript}")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Transcript: BUT|AFTER|ALL|THAT|COMMOTION|WAS|IT|ALL|WORTHWHILE|ABSOLUTELY|YES|THE|SET|DESIGN|WAS|BREATHTAKING|THE|ACTORS|WERE|INCREDIBLE|AND|THE|SONGS|WERE|MEMORABLE

# %% [markdown]
# # Method 1: CTC Segmentation using WAV2VEC2_ASR_BASE_960H
# Adapted from https://pytorch.org/audio/stable/tutorials/forced_alignment_tutorial.html
#
# This method uses a pretrained Wav2Vec2 English ASR model. Since the training dataset (Librespeech) contains standard English transcripts, we must first force-align each letter.
# Next, we map sequences of letters to the CMU Sphinx-40 phoneme set to get each phoneme start and end time.

# %%
bundle = torchaudio.pipelines.WAV2VEC2_ASR_BASE_960H
model = bundle.get_model().to(device)
letters = bundle.get_labels()
print(f"Letters: {letters}") # | is used as a word separator
letters_dictionary = {c: i for i, c in enumerate(letters)} # {letter: index} corresponding to the pretrained wav2vec2 model
tokens = [letters_dictionary[c] for c in transcript] # [index of first letter in transcript, index of second letter in transcript, ...]
print(f"Transcript tokens: {tokens}")

with torch.inference_mode():
    emissions, _ = model(waveform.to(device))
    emissions = torch.log_softmax(emissions, dim=-1) # According to the tutorial, this avoids numerical instability -- should test whether it reduces performance
emission = emissions[0].cpu().detach() # Shape: (Frames, Letters)
# Out:
# Letters: ('-', '|', 'E', 'T', 'A', 'O', 'N', 'I', 'H', 'S', 'R', 'D', 'L', 'U', 'M', 'W', 'C', 'F', 'G', 'Y', 'P', 'B', 'V', 'K', "'", 'X', 'J', 'Q', 'Z')
# Transcript tokens: [21, 13, 3, 1, 4, 17, 3, 2, 10, 1, 4, 12, 12, 1, 3, 8, 4, 3, 1, 16, 5, 14, 14, 5, 3, 7, 5, 6, 1, 15, 4, 9, 1, 7, 3, 1, 4, 12, 12, 1, 15, 5, 10, 3, 8, 15, 8, 7, 12, 2, 1, 4, 21, 9, 5, 12, 13, 3, 2, 12, 19, 1, 19, 2, 9, 1, 3, 8, 2, 1, 9, 2, 3, 1, 11, 2, 9, 7, 18, 6, 1, 15, 4, 9, 1, 21, 10, 2, 4, 3, 8, 3, 4, 23, 7, 6, 18, 1, 3, 8, 2, 1, 4, 16, 3, 5, 10, 9, 1, 15, 2, 10, 2, 1, 7, 6, 16, 10, 2, 11, 7, 21, 12, 2, 1, 4, 6, 11, 1, 3, 8, 2, 1, 9, 5, 6, 18, 9, 1, 15, 2, 10, 2, 1, 14, 2, 14, 5, 10, 4, 21, 12, 2]

# %%
# We use the CTC algorithm to find the most likely alignment timestamps between the wav2vec2 emission and the ground truth transcript.
# torch.nn.CTCLoss will give us the probability of the ground truth transcript matching the wav2vec2 output, but to get the most likely timestamps, we have to implement the CTC algorithm.

def get_trellis(emission, tokens, blank_id=0): 
    # Trellis is a matrix of (Frames, Transcript Letters) where each element is the probability of the transcript letter occuring at that frame. 
    # The general idea is that wav2vec2 outputs a probability for each letter in the vocab per frame, but we want to align a ground truth transcript who's letters may not perfectly match the maximum probabiliity of the wav2vec2 output at each frame.
    # Traversing the most likely path on the trellis will give us the most likely alignment timestamps between the wav2vec2 output and the ground truth transcript.
    # The following functions are adapted from https://pytorch.org/audio/stable/tutorials/forced_alignment_tutorial.html which has further details. 
    num_frame = emission.size(0)
    num_tokens = len(tokens)

    # Trellis has extra dimensions for both time axis and tokens.
    # The extra dim for tokens represents <SoS> (start-of-sentence)
    # The extra dim for time axis is for simplification of the code.
    trellis = torch.empty((num_frame + 1, num_tokens + 1))
    trellis[0, 0] = 0
    trellis[1:, 0] = torch.cumsum(emission[:, 0], 0)
    trellis[0, -num_tokens:] = -float("inf")
    trellis[-num_tokens:, 0] = float("inf")

    for t in range(num_frame):
        trellis[t + 1, 1:] = torch.maximum(
            # Score for staying at the same token
            trellis[t, 1:] + emission[t, blank_id],
            # Score for changing to the next token
            trellis[t, :-1] + emission[t, tokens],
        )
    return trellis


@dataclass
class Point:
    token_index: int
    time_index: int
    score: float


def backtrack(trellis, emission, tokens, blank_id=0):
    # Note:
    # j and t are indices for trellis, which has extra dimensions
    # for time and tokens at the beginning.
    # When referring to time frame index `T` in trellis,
    # the corresponding index in emission is `T-1`.
    # Similarly, when referring to token index `J` in trellis,
    # the corresponding index in transcript is `J-1`.
    j = trellis.size(1) - 1
    t_start = torch.argmax(trellis[:, j]).item()

    path = []
    for t in range(t_start, 0, -1):
        # 1. Figure out if the current position was stay or change
        # Note (again):
        # `emission[J-1]` is the emission at time frame `J` of trellis dimension.
        # Score for token staying the same from time frame J-1 to T.
        stayed = trellis[t - 1, j] + emission[t - 1, blank_id]
        # Score for token changing from C-1 at T-1 to J at T.
        changed = trellis[t - 1, j - 1] + emission[t - 1, tokens[j - 1]]

        # 2. Store the path with frame-wise probability.
        prob = emission[t - 1, tokens[j - 1] if changed > stayed else 0].exp().item()
        # Return token index and time index in non-trellis coordinate.
        path.append(Point(j - 1, t - 1, prob))

        # 3. Update the token
        if changed > stayed:
            j -= 1
            if j == 0:
                break
    else:
        raise ValueError("Failed to align")
    return path[::-1]

trellis = get_trellis(emission, tokens)

path = backtrack(trellis, emission, tokens)
for p in path:
    print(f"Letter: {transcript[p.token_index]}, Frame: {p.time_index}, Probability: {p.score}")
# Out:
# Letter: B, Frame: 30, Probability: 0.999861478805542
# Letter: B, Frame: 31, Probability: 0.9998544454574585
# Letter: B, Frame: 32, Probability: 0.9939178228378296
# Letter: U, Frame: 33, Probability: 0.999883770942688
# Letter: T, Frame: 34, Probability: 0.9998774528503418
# Letter: T, Frame: 35, Probability: 0.0041043516248464584
# Letter: |, Frame: 36, Probability: 0.9996973276138306
# Letter: |, Frame: 37, Probability: 0.9999879598617554
# Letter: |, Frame: 38, Probability: 0.9999998807907104
# Letter: A, Frame: 39, Probability: 0.9999967813491821
# Letter: A, Frame: 40, Probability: 0.009566818363964558
# Letter: F, Frame: 41, Probability: 0.9999899864196777
# Letter: F, Frame: 42, Probability: 0.9999974966049194
# Letter: F, Frame: 43, Probability: 0.043931275606155396
# Letter: T, Frame: 44, Probability: 0.9999842643737793
# Letter: T, Frame: 45, Probability: 0.9999840259552002
# Letter: E, Frame: 46, Probability: 0.9999806880950928
# Letter: R, Frame: 47, Probability: 0.9999549388885498
# Letter: R, Frame: 48, Probability: 0.048789944499731064
# Letter: R, Frame: 49, Probability: 0.00017343080253340304
# Letter: |, Frame: 50, Probability: 0.9999265670776367
# Letter: |, Frame: 51, Probability: 1.3359888271224918e-06
# Letter: |, Frame: 52, Probability: 0.05564167723059654
# Letter: |, Frame: 53, Probability: 0.9999992847442627
# Letter: |, Frame: 54, Probability: 0.9999996423721313
# Letter: |, Frame: 55, Probability: 0.9999992847442627
# Letter: |, Frame: 56, Probability: 0.9999992847442627
# Letter: |, Frame: 57, Probability: 0.9999998807907104
# Letter: |, Frame: 58, Probability: 0.9999998807907104
# Letter: |, Frame: 59, Probability: 0.9999992847442627
# Letter: A, Frame: 60, Probability: 0.9999972581863403
# Letter: L, Frame: 61, Probability: 0.9999899864196777
# Letter: L, Frame: 62, Probability: 0.9995248317718506
# Letter: L, Frame: 63, Probability: 0.999996542930603
# Letter: L, Frame: 64, Probability: 0.002462369157001376
# Letter: L, Frame: 65, Probability: 0.9994526505470276
# Letter: L, Frame: 66, Probability: 8.275446816696785e-07
# Letter: |, Frame: 67, Probability: 0.9993131160736084
# Letter: |, Frame: 68, Probability: 1.6942321963142604e-05
# Letter: T, Frame: 69, Probability: 0.9998489618301392
# Letter: T, Frame: 70, Probability: 0.09828947484493256
# Letter: H, Frame: 71, Probability: 0.9998537302017212
# Letter: H, Frame: 72, Probability: 0.9999998807907104
# Letter: H, Frame: 73, Probability: 0.9999035596847534
# Letter: A, Frame: 74, Probability: 0.9997001886367798
# Letter: A, Frame: 75, Probability: 0.049107857048511505
# Letter: T, Frame: 76, Probability: 0.9918871521949768
# Letter: T, Frame: 77, Probability: 1.704547685221769e-05
# Letter: |, Frame: 78, Probability: 0.9999650716781616
# Letter: |, Frame: 79, Probability: 0.9743887186050415
# Letter: C, Frame: 80, Probability: 0.9999885559082031
# Letter: C, Frame: 81, Probability: 0.9999843835830688
# Letter: C, Frame: 82, Probability: 0.9999985694885254
# Letter: O, Frame: 83, Probability: 0.9999860525131226
# Letter: M, Frame: 84, Probability: 0.9999432563781738
# Letter: M, Frame: 85, Probability: 0.999998927116394
# Letter: M, Frame: 86, Probability: 0.9999949932098389
# Letter: M, Frame: 87, Probability: 0.9999918937683105
# Letter: M, Frame: 88, Probability: 0.9959753155708313
# Letter: M, Frame: 89, Probability: 0.9999979734420776
# Letter: M, Frame: 90, Probability: 0.9999997615814209
# Letter: O, Frame: 91, Probability: 0.9999829530715942
# Letter: O, Frame: 92, Probability: 0.9998372793197632
# Letter: O, Frame: 93, Probability: 0.9999836683273315
# Letter: O, Frame: 94, Probability: 0.9999891519546509
# Letter: T, Frame: 95, Probability: 0.9999520778656006
# Letter: T, Frame: 96, Probability: 0.9964683055877686
# Letter: T, Frame: 97, Probability: 0.005502030253410339
# Letter: I, Frame: 98, Probability: 0.999992847442627
# Letter: I, Frame: 99, Probability: 0.9999957084655762
# Letter: I, Frame: 100, Probability: 0.8806226849555969
# Letter: O, Frame: 101, Probability: 0.9999808073043823
# Letter: N, Frame: 102, Probability: 0.9999746084213257
# Letter: N, Frame: 103, Probability: 0.5869104266166687
# Letter: N, Frame: 104, Probability: 0.9683132171630859
# Letter: N, Frame: 105, Probability: 1.7444348259232356e-06
# Letter: |, Frame: 106, Probability: 0.9997908473014832
# Letter: |, Frame: 107, Probability: 2.0033211001191376e-07
# Letter: |, Frame: 108, Probability: 0.023826563730835915
# Letter: |, Frame: 109, Probability: 1.0
# Letter: |, Frame: 110, Probability: 1.0
# Letter: |, Frame: 111, Probability: 1.0
# Letter: |, Frame: 112, Probability: 1.0
# Letter: |, Frame: 113, Probability: 1.0
# Letter: |, Frame: 114, Probability: 1.0
# Letter: |, Frame: 115, Probability: 1.0
# Letter: |, Frame: 116, Probability: 1.0
# Letter: |, Frame: 117, Probability: 1.0
# Letter: |, Frame: 118, Probability: 1.0
# Letter: |, Frame: 119, Probability: 1.0
# Letter: |, Frame: 120, Probability: 1.0
# Letter: |, Frame: 121, Probability: 1.0
# Letter: |, Frame: 122, Probability: 1.0
# Letter: |, Frame: 123, Probability: 1.0
# Letter: |, Frame: 124, Probability: 1.0
# Letter: |, Frame: 125, Probability: 1.0
# Letter: |, Frame: 126, Probability: 1.0
# Letter: |, Frame: 127, Probability: 1.0
# Letter: |, Frame: 128, Probability: 1.0
# Letter: |, Frame: 129, Probability: 1.0
# Letter: |, Frame: 130, Probability: 1.0
# Letter: |, Frame: 131, Probability: 1.0
# Letter: |, Frame: 132, Probability: 1.0
# Letter: |, Frame: 133, Probability: 1.0
# Letter: |, Frame: 134, Probability: 1.0
# Letter: |, Frame: 135, Probability: 1.0
# Letter: |, Frame: 136, Probability: 1.0
# Letter: |, Frame: 137, Probability: 1.0
# Letter: |, Frame: 138, Probability: 1.0
# Letter: |, Frame: 139, Probability: 1.0
# Letter: |, Frame: 140, Probability: 1.0
# Letter: |, Frame: 141, Probability: 0.9999998807907104
# Letter: |, Frame: 142, Probability: 0.9999998807907104
# Letter: |, Frame: 143, Probability: 0.9957707524299622
# Letter: W, Frame: 144, Probability: 0.9999905824661255
# Letter: W, Frame: 145, Probability: 0.6076387166976929
# Letter: W, Frame: 146, Probability: 0.9999985694885254
# Letter: W, Frame: 147, Probability: 0.9999998807907104
# Letter: W, Frame: 148, Probability: 0.04002976417541504
# Letter: A, Frame: 149, Probability: 0.9999910593032837
# Letter: A, Frame: 150, Probability: 0.9420078992843628
# Letter: S, Frame: 151, Probability: 0.9999603033065796
# Letter: S, Frame: 152, Probability: 0.99428790807724
# Letter: S, Frame: 153, Probability: 7.597277090098942e-06
# Letter: |, Frame: 154, Probability: 0.9999411106109619
# Letter: |, Frame: 155, Probability: 0.004339195322245359
# Letter: I, Frame: 156, Probability: 0.999445378780365
# Letter: T, Frame: 157, Probability: 0.9992751479148865
# Letter: |, Frame: 158, Probability: 0.9999638795852661
# Letter: |, Frame: 159, Probability: 0.00017446745187044144
# Letter: |, Frame: 160, Probability: 0.9999806880950928
# Letter: |, Frame: 161, Probability: 0.9999994039535522
# Letter: A, Frame: 162, Probability: 0.999991774559021
# Letter: L, Frame: 163, Probability: 0.9999486207962036
# Letter: L, Frame: 164, Probability: 0.7194664478302002
# Letter: L, Frame: 165, Probability: 0.9999974966049194
# Letter: L, Frame: 166, Probability: 0.9999101161956787
# Letter: L, Frame: 167, Probability: 0.3086058497428894
# Letter: |, Frame: 168, Probability: 0.9991896748542786
# Letter: |, Frame: 169, Probability: 0.0014508165186271071
# Letter: |, Frame: 170, Probability: 0.998346209526062
# Letter: W, Frame: 171, Probability: 0.9999979734420776
# Letter: W, Frame: 172, Probability: 0.7980139851570129
# Letter: W, Frame: 173, Probability: 1.0
# Letter: O, Frame: 174, Probability: 0.9999969005584717
# Letter: O, Frame: 175, Probability: 0.0015305017586797476
# Letter: R, Frame: 176, Probability: 0.9999958276748657
# Letter: R, Frame: 177, Probability: 0.9999963045120239
# Letter: T, Frame: 178, Probability: 0.9999803304672241
# Letter: H, Frame: 179, Probability: 0.9999186992645264
# Letter: H, Frame: 180, Probability: 0.0007717086118645966
# Letter: H, Frame: 181, Probability: 0.9977496266365051
# Letter: H, Frame: 182, Probability: 0.05170641466975212
# Letter: H, Frame: 183, Probability: 0.023762820288538933
# Letter: H, Frame: 184, Probability: 0.9958912134170532
# Letter: H, Frame: 185, Probability: 0.998065173625946
# Letter: W, Frame: 186, Probability: 0.9999635219573975
# Letter: H, Frame: 187, Probability: 0.9998385906219482
# Letter: H, Frame: 188, Probability: 0.9993501305580139
# Letter: H, Frame: 189, Probability: 0.9999988079071045
# Letter: H, Frame: 190, Probability: 0.999998927116394
# Letter: H, Frame: 191, Probability: 0.9999991655349731
# Letter: H, Frame: 192, Probability: 0.9999996423721313
# Letter: H, Frame: 193, Probability: 0.9987472295761108
# Letter: I, Frame: 194, Probability: 0.9999939203262329
# Letter: I, Frame: 195, Probability: 0.20175708830356598
# Letter: I, Frame: 196, Probability: 0.0017782320501282811
# Letter: L, Frame: 197, Probability: 0.9999722242355347
# Letter: E, Frame: 198, Probability: 0.9999576807022095
# Letter: E, Frame: 199, Probability: 0.003312986809760332
# Letter: E, Frame: 200, Probability: 3.278735505318764e-08
# Letter: |, Frame: 201, Probability: 0.9995647072792053
# Letter: |, Frame: 202, Probability: 2.423686851216189e-08
# Letter: |, Frame: 203, Probability: 4.59421653431491e-06
# Letter: |, Frame: 204, Probability: 0.999976396560669
# Letter: |, Frame: 205, Probability: 1.0
# Letter: |, Frame: 206, Probability: 1.0
# Letter: |, Frame: 207, Probability: 1.0
# Letter: |, Frame: 208, Probability: 1.0
# Letter: |, Frame: 209, Probability: 1.0
# Letter: |, Frame: 210, Probability: 1.0
# Letter: |, Frame: 211, Probability: 1.0
# Letter: |, Frame: 212, Probability: 1.0
# Letter: |, Frame: 213, Probability: 1.0
# Letter: |, Frame: 214, Probability: 1.0
# Letter: |, Frame: 215, Probability: 1.0
# Letter: |, Frame: 216, Probability: 1.0
# Letter: |, Frame: 217, Probability: 1.0
# Letter: |, Frame: 218, Probability: 1.0
# Letter: |, Frame: 219, Probability: 1.0
# Letter: |, Frame: 220, Probability: 1.0
# Letter: |, Frame: 221, Probability: 1.0
# Letter: |, Frame: 222, Probability: 1.0
# Letter: |, Frame: 223, Probability: 1.0
# Letter: |, Frame: 224, Probability: 1.0
# Letter: |, Frame: 225, Probability: 1.0
# Letter: |, Frame: 226, Probability: 1.0
# Letter: |, Frame: 227, Probability: 1.0
# Letter: |, Frame: 228, Probability: 1.0
# Letter: |, Frame: 229, Probability: 1.0
# Letter: |, Frame: 230, Probability: 1.0
# Letter: |, Frame: 231, Probability: 1.0
# Letter: |, Frame: 232, Probability: 1.0
# Letter: |, Frame: 233, Probability: 1.0
# Letter: |, Frame: 234, Probability: 1.0
# Letter: |, Frame: 235, Probability: 1.0
# Letter: |, Frame: 236, Probability: 1.0
# Letter: |, Frame: 237, Probability: 1.0
# Letter: |, Frame: 238, Probability: 1.0
# Letter: |, Frame: 239, Probability: 1.0
# Letter: |, Frame: 240, Probability: 1.0
# Letter: |, Frame: 241, Probability: 0.9999998807907104
# Letter: |, Frame: 242, Probability: 1.0
# Letter: |, Frame: 243, Probability: 1.0
# Letter: |, Frame: 244, Probability: 1.0
# Letter: |, Frame: 245, Probability: 1.0
# Letter: |, Frame: 246, Probability: 1.0
# Letter: |, Frame: 247, Probability: 1.0
# Letter: |, Frame: 248, Probability: 1.0
# Letter: |, Frame: 249, Probability: 1.0
# Letter: |, Frame: 250, Probability: 1.0
# Letter: |, Frame: 251, Probability: 1.0
# Letter: |, Frame: 252, Probability: 0.9999997615814209
# Letter: |, Frame: 253, Probability: 1.0
# Letter: |, Frame: 254, Probability: 1.0
# Letter: |, Frame: 255, Probability: 1.0
# Letter: |, Frame: 256, Probability: 1.0
# Letter: |, Frame: 257, Probability: 1.0
# Letter: |, Frame: 258, Probability: 1.0
# Letter: |, Frame: 259, Probability: 1.0
# Letter: |, Frame: 260, Probability: 1.0
# Letter: |, Frame: 261, Probability: 0.9999998807907104
# Letter: |, Frame: 262, Probability: 0.9999997615814209
# Letter: |, Frame: 263, Probability: 0.9999998807907104
# Letter: |, Frame: 264, Probability: 0.9999998807907104
# Letter: |, Frame: 265, Probability: 0.9999998807907104
# Letter: |, Frame: 266, Probability: 1.0
# Letter: |, Frame: 267, Probability: 1.0
# Letter: |, Frame: 268, Probability: 1.0
# Letter: |, Frame: 269, Probability: 0.9999998807907104
# Letter: |, Frame: 270, Probability: 1.0
# Letter: |, Frame: 271, Probability: 1.0
# Letter: |, Frame: 272, Probability: 1.0
# Letter: |, Frame: 273, Probability: 0.9999995231628418
# Letter: |, Frame: 274, Probability: 0.9999994039535522
# Letter: |, Frame: 275, Probability: 0.9999991655349731
# Letter: |, Frame: 276, Probability: 0.9999992847442627
# Letter: |, Frame: 277, Probability: 0.9999994039535522
# Letter: |, Frame: 278, Probability: 0.9999994039535522
# Letter: |, Frame: 279, Probability: 0.9994980096817017
# Letter: A, Frame: 280, Probability: 0.999994158744812
# Letter: A, Frame: 281, Probability: 0.022883929312229156
# Letter: A, Frame: 282, Probability: 0.01567050628364086
# Letter: B, Frame: 283, Probability: 0.9999934434890747
# Letter: B, Frame: 284, Probability: 0.9881872534751892
# Letter: B, Frame: 285, Probability: 0.9999982118606567
# Letter: B, Frame: 286, Probability: 0.9999970197677612
# Letter: B, Frame: 287, Probability: 0.9999889135360718
# Letter: B, Frame: 288, Probability: 0.023685086518526077
# Letter: S, Frame: 289, Probability: 0.9999979734420776
# Letter: S, Frame: 290, Probability: 0.9996421337127686
# Letter: S, Frame: 291, Probability: 0.9999998807907104
# Letter: S, Frame: 292, Probability: 1.0
# Letter: S, Frame: 293, Probability: 0.9999998807907104
# Letter: O, Frame: 294, Probability: 0.9999817609786987
# Letter: O, Frame: 295, Probability: 0.992274820804596
# Letter: O, Frame: 296, Probability: 0.9999963045120239
# Letter: L, Frame: 297, Probability: 0.9999830722808838
# Letter: L, Frame: 298, Probability: 2.923938700405415e-05
# Letter: L, Frame: 299, Probability: 0.9970539808273315
# Letter: L, Frame: 300, Probability: 0.9999994039535522
# Letter: L, Frame: 301, Probability: 0.9999997615814209
# Letter: L, Frame: 302, Probability: 0.999970555305481
# Letter: U, Frame: 303, Probability: 0.9998922348022461
# Letter: U, Frame: 304, Probability: 0.9997802376747131
# Letter: U, Frame: 305, Probability: 7.386528886854649e-05
# Letter: T, Frame: 306, Probability: 0.9999136924743652
# Letter: E, Frame: 307, Probability: 0.9999102354049683
# Letter: E, Frame: 308, Probability: 0.9979700446128845
# Letter: E, Frame: 309, Probability: 0.9999305009841919
# Letter: L, Frame: 310, Probability: 0.9997031092643738
# Letter: L, Frame: 311, Probability: 0.0010582904797047377
# Letter: L, Frame: 312, Probability: 0.9999725818634033
# Letter: Y, Frame: 313, Probability: 0.9999916553497314
# Letter: Y, Frame: 314, Probability: 0.10697959363460541
# Letter: Y, Frame: 315, Probability: 4.571903389205545e-08
# Letter: |, Frame: 316, Probability: 0.9999815225601196
# Letter: |, Frame: 317, Probability: 0.6063161492347717
# Letter: Y, Frame: 318, Probability: 0.9998785257339478
# Letter: Y, Frame: 319, Probability: 0.9999432563781738
# Letter: Y, Frame: 320, Probability: 0.9999966621398926
# Letter: Y, Frame: 321, Probability: 0.999998927116394
# Letter: Y, Frame: 322, Probability: 0.9999988079071045
# Letter: Y, Frame: 323, Probability: 0.9999990463256836
# Letter: Y, Frame: 324, Probability: 0.9978384375572205
# Letter: E, Frame: 325, Probability: 0.9999645948410034
# Letter: E, Frame: 326, Probability: 0.962921142578125
# Letter: E, Frame: 327, Probability: 0.9999493360519409
# Letter: S, Frame: 328, Probability: 0.999980092048645
# Letter: S, Frame: 329, Probability: 0.9990980625152588
# Letter: S, Frame: 330, Probability: 0.0002494373475201428
# Letter: |, Frame: 331, Probability: 0.9999295473098755
# Letter: |, Frame: 332, Probability: 2.3890554530225927e-06
# Letter: |, Frame: 333, Probability: 0.0019420958124101162
# Letter: |, Frame: 334, Probability: 0.9999707937240601
# Letter: |, Frame: 335, Probability: 0.9999998807907104
# Letter: |, Frame: 336, Probability: 1.0
# Letter: |, Frame: 337, Probability: 1.0
# Letter: |, Frame: 338, Probability: 1.0
# Letter: |, Frame: 339, Probability: 1.0
# Letter: |, Frame: 340, Probability: 1.0
# Letter: |, Frame: 341, Probability: 1.0
# Letter: |, Frame: 342, Probability: 1.0
# Letter: |, Frame: 343, Probability: 1.0
# Letter: |, Frame: 344, Probability: 1.0
# Letter: |, Frame: 345, Probability: 1.0
# Letter: |, Frame: 346, Probability: 1.0
# Letter: |, Frame: 347, Probability: 1.0
# Letter: |, Frame: 348, Probability: 1.0
# Letter: |, Frame: 349, Probability: 1.0
# Letter: |, Frame: 350, Probability: 1.0
# Letter: |, Frame: 351, Probability: 1.0
# Letter: |, Frame: 352, Probability: 1.0
# Letter: |, Frame: 353, Probability: 1.0
# Letter: |, Frame: 354, Probability: 1.0
# Letter: |, Frame: 355, Probability: 1.0
# Letter: |, Frame: 356, Probability: 1.0
# Letter: |, Frame: 357, Probability: 1.0
# Letter: |, Frame: 358, Probability: 1.0
# Letter: |, Frame: 359, Probability: 1.0
# Letter: |, Frame: 360, Probability: 0.9999998807907104
# Letter: |, Frame: 361, Probability: 1.0
# Letter: |, Frame: 362, Probability: 1.0
# Letter: |, Frame: 363, Probability: 1.0
# Letter: |, Frame: 364, Probability: 1.0
# Letter: |, Frame: 365, Probability: 1.0
# Letter: |, Frame: 366, Probability: 1.0
# Letter: |, Frame: 367, Probability: 1.0
# Letter: |, Frame: 368, Probability: 1.0
# Letter: |, Frame: 369, Probability: 1.0
# Letter: |, Frame: 370, Probability: 1.0
# Letter: |, Frame: 371, Probability: 0.9999997615814209
# Letter: |, Frame: 372, Probability: 0.9999992847442627
# Letter: |, Frame: 373, Probability: 0.999995231628418
# Letter: |, Frame: 374, Probability: 0.6814523935317993
# Letter: T, Frame: 375, Probability: 0.999373733997345
# Letter: H, Frame: 376, Probability: 0.9988493919372559
# Letter: H, Frame: 377, Probability: 0.08548610657453537
# Letter: E, Frame: 378, Probability: 0.9992004036903381
# Letter: E, Frame: 379, Probability: 0.01961502991616726
# Letter: |, Frame: 380, Probability: 0.9996035695075989
# Letter: |, Frame: 381, Probability: 0.9873976111412048
# Letter: |, Frame: 382, Probability: 0.9999642372131348
# Letter: S, Frame: 383, Probability: 0.9987068176269531
# Letter: S, Frame: 384, Probability: 0.9997233748435974
# Letter: S, Frame: 385, Probability: 0.9999440908432007
# Letter: S, Frame: 386, Probability: 0.9999899864196777
# Letter: E, Frame: 387, Probability: 0.9952409267425537
# Letter: E, Frame: 388, Probability: 0.9985167384147644
# Letter: E, Frame: 389, Probability: 0.9986984729766846
# Letter: E, Frame: 390, Probability: 0.9995811581611633
# Letter: T, Frame: 391, Probability: 0.9979825019836426
# Letter: T, Frame: 392, Probability: 0.013283041305840015
# Letter: T, Frame: 393, Probability: 0.20378559827804565
# Letter: |, Frame: 394, Probability: 0.9999350309371948
# Letter: D, Frame: 395, Probability: 0.9999780654907227
# Letter: D, Frame: 396, Probability: 0.08428183197975159
# Letter: D, Frame: 397, Probability: 0.9999997615814209
# Letter: E, Frame: 398, Probability: 0.9999890327453613
# Letter: E, Frame: 399, Probability: 0.4709557890892029
# Letter: E, Frame: 400, Probability: 0.9999960660934448
# Letter: E, Frame: 401, Probability: 0.9998369216918945
# Letter: S, Frame: 402, Probability: 0.9999909400939941
# Letter: S, Frame: 403, Probability: 0.9999899864196777
# Letter: S, Frame: 404, Probability: 0.9999983310699463
# Letter: S, Frame: 405, Probability: 0.9999988079071045
# Letter: S, Frame: 406, Probability: 0.9999994039535522
# Letter: S, Frame: 407, Probability: 0.9999996423721313
# Letter: S, Frame: 408, Probability: 0.9999998807907104
# Letter: S, Frame: 409, Probability: 1.0
# Letter: I, Frame: 410, Probability: 0.9999984502792358
# Letter: I, Frame: 411, Probability: 0.0014875796623528004
# Letter: G, Frame: 412, Probability: 0.9999245405197144
# Letter: G, Frame: 413, Probability: 0.06871162354946136
# Letter: N, Frame: 414, Probability: 0.9995891451835632
# Letter: N, Frame: 415, Probability: 0.7342129945755005
# Letter: N, Frame: 416, Probability: 0.9836984872817993
# Letter: N, Frame: 417, Probability: 0.001214714371599257
# Letter: |, Frame: 418, Probability: 0.9999221563339233
# Letter: |, Frame: 419, Probability: 6.019221387987272e-08
# Letter: |, Frame: 420, Probability: 0.9294688701629639
# Letter: |, Frame: 421, Probability: 1.0
# Letter: |, Frame: 422, Probability: 1.0
# Letter: |, Frame: 423, Probability: 0.9999980926513672
# Letter: W, Frame: 424, Probability: 0.9999526739120483
# Letter: W, Frame: 425, Probability: 0.8062976598739624
# Letter: W, Frame: 426, Probability: 0.9999985694885254
# Letter: W, Frame: 427, Probability: 0.9984773993492126
# Letter: A, Frame: 428, Probability: 0.9999738931655884
# Letter: S, Frame: 429, Probability: 0.999987006187439
# Letter: S, Frame: 430, Probability: 0.11310148239135742
# Letter: |, Frame: 431, Probability: 0.9999436140060425
# Letter: |, Frame: 432, Probability: 2.3989937147916862e-08
# Letter: |, Frame: 433, Probability: 0.00015046288899611682
# Letter: |, Frame: 434, Probability: 0.9999804496765137
# Letter: |, Frame: 435, Probability: 0.9999992847442627
# Letter: |, Frame: 436, Probability: 0.9999978542327881
# Letter: B, Frame: 437, Probability: 0.999995231628418
# Letter: B, Frame: 438, Probability: 0.9742138981819153
# Letter: B, Frame: 439, Probability: 0.9997016787528992
# Letter: B, Frame: 440, Probability: 0.6795594692230225
# Letter: R, Frame: 441, Probability: 0.999894380569458
# Letter: R, Frame: 442, Probability: 0.12279988825321198
# Letter: E, Frame: 443, Probability: 0.9983875751495361
# Letter: E, Frame: 444, Probability: 0.4002453088760376
# Letter: A, Frame: 445, Probability: 0.9989252686500549
# Letter: A, Frame: 446, Probability: 0.9999312162399292
# Letter: A, Frame: 447, Probability: 0.8907516598701477
# Letter: T, Frame: 448, Probability: 0.9998922348022461
# Letter: H, Frame: 449, Probability: 0.9996943473815918
# Letter: H, Frame: 450, Probability: 0.9993504881858826
# Letter: H, Frame: 451, Probability: 0.4380927085876465
# Letter: H, Frame: 452, Probability: 0.36512938141822815
# Letter: T, Frame: 453, Probability: 0.9994242191314697
# Letter: T, Frame: 454, Probability: 0.9997084736824036
# Letter: T, Frame: 455, Probability: 0.9999748468399048
# Letter: T, Frame: 456, Probability: 0.9999841451644897
# Letter: T, Frame: 457, Probability: 0.9999909400939941
# Letter: A, Frame: 458, Probability: 0.9998235106468201
# Letter: A, Frame: 459, Probability: 0.9859727621078491
# Letter: A, Frame: 460, Probability: 0.9999417066574097
# Letter: K, Frame: 461, Probability: 0.9998806715011597
# Letter: K, Frame: 462, Probability: 0.9997813105583191
# Letter: K, Frame: 463, Probability: 0.9999417066574097
# Letter: K, Frame: 464, Probability: 0.9999781847000122
# Letter: K, Frame: 465, Probability: 0.9999892711639404
# Letter: I, Frame: 466, Probability: 0.9997249245643616
# Letter: N, Frame: 467, Probability: 0.9998700618743896
# Letter: N, Frame: 468, Probability: 0.01624254137277603
# Letter: G, Frame: 469, Probability: 0.999632716178894
# Letter: G, Frame: 470, Probability: 0.6394925117492676
# Letter: G, Frame: 471, Probability: 1.5438455420735409e-06
# Letter: |, Frame: 472, Probability: 0.999945878982544
# Letter: |, Frame: 473, Probability: 0.001695463084615767
# Letter: |, Frame: 474, Probability: 0.999997615814209
# Letter: |, Frame: 475, Probability: 1.0
# Letter: |, Frame: 476, Probability: 1.0
# Letter: |, Frame: 477, Probability: 1.0
# Letter: |, Frame: 478, Probability: 1.0
# Letter: |, Frame: 479, Probability: 1.0
# Letter: |, Frame: 480, Probability: 1.0
# Letter: |, Frame: 481, Probability: 1.0
# Letter: |, Frame: 482, Probability: 1.0
# Letter: |, Frame: 483, Probability: 1.0
# Letter: |, Frame: 484, Probability: 1.0
# Letter: |, Frame: 485, Probability: 1.0
# Letter: |, Frame: 486, Probability: 1.0
# Letter: |, Frame: 487, Probability: 0.9999997615814209
# Letter: |, Frame: 488, Probability: 0.9999990463256836
# Letter: |, Frame: 489, Probability: 0.8646735548973083
# Letter: T, Frame: 490, Probability: 0.9996761083602905
# Letter: H, Frame: 491, Probability: 0.9998263716697693
# Letter: E, Frame: 492, Probability: 0.9994895458221436
# Letter: E, Frame: 493, Probability: 0.0050053526647388935
# Letter: E, Frame: 494, Probability: 0.1345120668411255
# Letter: |, Frame: 495, Probability: 0.9999701976776123
# Letter: |, Frame: 496, Probability: 0.7931169271469116
# Letter: |, Frame: 497, Probability: 0.9999990463256836
# Letter: |, Frame: 498, Probability: 0.9999994039535522
# Letter: |, Frame: 499, Probability: 0.9999998807907104
# Letter: |, Frame: 500, Probability: 0.9999998807907104
# Letter: A, Frame: 501, Probability: 0.9999947547912598
# Letter: C, Frame: 502, Probability: 0.9998499155044556
# Letter: C, Frame: 503, Probability: 0.9788074493408203
# Letter: C, Frame: 504, Probability: 0.9999998807907104
# Letter: C, Frame: 505, Probability: 0.9999901056289673
# Letter: T, Frame: 506, Probability: 0.9999903440475464
# Letter: T, Frame: 507, Probability: 0.999552309513092
# Letter: T, Frame: 508, Probability: 0.9999963045120239
# Letter: T, Frame: 509, Probability: 0.9999990463256836
# Letter: O, Frame: 510, Probability: 0.999562680721283
# Letter: R, Frame: 511, Probability: 0.9998811483383179
# Letter: R, Frame: 512, Probability: 0.08720806986093521
# Letter: R, Frame: 513, Probability: 0.999809205532074
# Letter: R, Frame: 514, Probability: 0.49071425199508667
# Letter: S, Frame: 515, Probability: 0.9999464750289917
# Letter: S, Frame: 516, Probability: 0.00540597690269351
# Letter: |, Frame: 517, Probability: 0.9999502897262573
# Letter: |, Frame: 518, Probability: 5.089256092105643e-07
# Letter: |, Frame: 519, Probability: 0.568576991558075
# Letter: |, Frame: 520, Probability: 0.9999951124191284
# Letter: W, Frame: 521, Probability: 0.9999876022338867
# Letter: W, Frame: 522, Probability: 0.03582840412855148
# Letter: W, Frame: 523, Probability: 0.9999924898147583
# Letter: W, Frame: 524, Probability: 0.9999996423721313
# Letter: W, Frame: 525, Probability: 0.9999959468841553
# Letter: E, Frame: 526, Probability: 0.9997321963310242
# Letter: R, Frame: 527, Probability: 0.9999494552612305
# Letter: R, Frame: 528, Probability: 0.0149298757314682
# Letter: R, Frame: 529, Probability: 0.959703266620636
# Letter: E, Frame: 530, Probability: 0.9999231100082397
# Letter: E, Frame: 531, Probability: 0.5403226017951965
# Letter: E, Frame: 532, Probability: 8.714773969131784e-08
# Letter: |, Frame: 533, Probability: 0.9998899698257446
# Letter: |, Frame: 534, Probability: 0.00017963470600079745
# Letter: |, Frame: 535, Probability: 0.9999943971633911
# Letter: |, Frame: 536, Probability: 1.0
# Letter: |, Frame: 537, Probability: 1.0
# Letter: |, Frame: 538, Probability: 0.9999990463256836
# Letter: |, Frame: 539, Probability: 0.9999980926513672
# Letter: |, Frame: 540, Probability: 0.9999992847442627
# Letter: I, Frame: 541, Probability: 0.9999717473983765
# Letter: N, Frame: 542, Probability: 0.9999915361404419
# Letter: N, Frame: 543, Probability: 0.6620292663574219
# Letter: N, Frame: 544, Probability: 0.9999984502792358
# Letter: N, Frame: 545, Probability: 0.9999954700469971
# Letter: N, Frame: 546, Probability: 0.9999922513961792
# Letter: N, Frame: 547, Probability: 0.9999942779541016
# Letter: N, Frame: 548, Probability: 0.9999970197677612
# Letter: N, Frame: 549, Probability: 0.9999991655349731
# Letter: N, Frame: 550, Probability: 0.9970731735229492
# Letter: C, Frame: 551, Probability: 0.9999972581863403
# Letter: C, Frame: 552, Probability: 0.999698281288147
# Letter: C, Frame: 553, Probability: 0.9921649694442749
# Letter: R, Frame: 554, Probability: 0.9999951124191284
# Letter: R, Frame: 555, Probability: 0.40111005306243896
# Letter: R, Frame: 556, Probability: 1.0
# Letter: R, Frame: 557, Probability: 0.9999978542327881
# Letter: E, Frame: 558, Probability: 0.9999926090240479
# Letter: E, Frame: 559, Probability: 0.8688491582870483
# Letter: E, Frame: 560, Probability: 0.9999966621398926
# Letter: D, Frame: 561, Probability: 0.999990701675415
# Letter: D, Frame: 562, Probability: 0.9317392706871033
# Letter: D, Frame: 563, Probability: 0.9948431253433228
# Letter: I, Frame: 564, Probability: 0.9999725818634033
# Letter: I, Frame: 565, Probability: 0.9940417408943176
# Letter: I, Frame: 566, Probability: 0.5218126177787781
# Letter: B, Frame: 567, Probability: 0.9999860525131226
# Letter: B, Frame: 568, Probability: 0.9997245669364929
# Letter: B, Frame: 569, Probability: 0.9999043941497803
# Letter: B, Frame: 570, Probability: 2.2386462660506368e-05
# Letter: L, Frame: 571, Probability: 0.9999829530715942
# Letter: L, Frame: 572, Probability: 0.7887454628944397
# Letter: E, Frame: 573, Probability: 0.9995125532150269
# Letter: E, Frame: 574, Probability: 0.03594507277011871
# Letter: |, Frame: 575, Probability: 0.9998732805252075
# Letter: |, Frame: 576, Probability: 5.318622788763605e-05
# Letter: |, Frame: 577, Probability: 0.9999583959579468
# Letter: |, Frame: 578, Probability: 0.9999997615814209
# Letter: |, Frame: 579, Probability: 0.9999998807907104
# Letter: |, Frame: 580, Probability: 1.0
# Letter: |, Frame: 581, Probability: 1.0
# Letter: |, Frame: 582, Probability: 1.0
# Letter: |, Frame: 583, Probability: 1.0
# Letter: |, Frame: 584, Probability: 1.0
# Letter: |, Frame: 585, Probability: 1.0
# Letter: |, Frame: 586, Probability: 1.0
# Letter: |, Frame: 587, Probability: 0.9999997615814209
# Letter: |, Frame: 588, Probability: 1.0
# Letter: |, Frame: 589, Probability: 1.0
# Letter: |, Frame: 590, Probability: 1.0
# Letter: |, Frame: 591, Probability: 1.0
# Letter: |, Frame: 592, Probability: 0.9999998807907104
# Letter: |, Frame: 593, Probability: 1.0
# Letter: |, Frame: 594, Probability: 1.0
# Letter: |, Frame: 595, Probability: 1.0
# Letter: |, Frame: 596, Probability: 1.0
# Letter: |, Frame: 597, Probability: 1.0
# Letter: |, Frame: 598, Probability: 1.0
# Letter: |, Frame: 599, Probability: 1.0
# Letter: |, Frame: 600, Probability: 1.0
# Letter: |, Frame: 601, Probability: 0.9999996423721313
# Letter: |, Frame: 602, Probability: 0.9999967813491821
# Letter: |, Frame: 603, Probability: 0.999994158744812
# Letter: |, Frame: 604, Probability: 0.9999949932098389
# Letter: |, Frame: 605, Probability: 0.6108755469322205
# Letter: A, Frame: 606, Probability: 0.9999731779098511
# Letter: N, Frame: 607, Probability: 0.9998660087585449
# Letter: N, Frame: 608, Probability: 0.07043091952800751
# Letter: D, Frame: 609, Probability: 0.998668909072876
# Letter: D, Frame: 610, Probability: 0.00011231844109715894
# Letter: |, Frame: 611, Probability: 0.9999732971191406
# Letter: |, Frame: 612, Probability: 9.22486560739344e-06
# Letter: T, Frame: 613, Probability: 0.9971627593040466
# Letter: H, Frame: 614, Probability: 0.9976112842559814
# Letter: E, Frame: 615, Probability: 0.9980568289756775
# Letter: E, Frame: 616, Probability: 0.00295477663166821
# Letter: |, Frame: 617, Probability: 0.9998502731323242
# Letter: |, Frame: 618, Probability: 0.005612466484308243
# Letter: |, Frame: 619, Probability: 0.9998177886009216
# Letter: S, Frame: 620, Probability: 0.9991532564163208
# Letter: S, Frame: 621, Probability: 0.0013638553209602833
# Letter: S, Frame: 622, Probability: 0.999921441078186
# Letter: S, Frame: 623, Probability: 0.9999675750732422
# Letter: S, Frame: 624, Probability: 0.9999964237213135
# Letter: S, Frame: 625, Probability: 0.9999982118606567
# Letter: S, Frame: 626, Probability: 0.9999990463256836
# Letter: S, Frame: 627, Probability: 0.9999994039535522
# Letter: O, Frame: 628, Probability: 0.9996933937072754
# Letter: O, Frame: 629, Probability: 0.9998346567153931
# Letter: O, Frame: 630, Probability: 0.40221208333969116
# Letter: N, Frame: 631, Probability: 0.9999669790267944
# Letter: G, Frame: 632, Probability: 0.9998082518577576
# Letter: G, Frame: 633, Probability: 0.5503820776939392
# Letter: G, Frame: 634, Probability: 0.9998098015785217
# Letter: G, Frame: 635, Probability: 0.9916719794273376
# Letter: S, Frame: 636, Probability: 0.999901533126831
# Letter: S, Frame: 637, Probability: 0.30076637864112854
# Letter: |, Frame: 638, Probability: 0.9999909400939941
# Letter: |, Frame: 639, Probability: 0.027368810027837753
# Letter: |, Frame: 640, Probability: 0.009201020933687687
# Letter: W, Frame: 641, Probability: 0.9996882677078247
# Letter: W, Frame: 642, Probability: 0.999992847442627
# Letter: E, Frame: 643, Probability: 0.9998422861099243
# Letter: R, Frame: 644, Probability: 0.9999393224716187
# Letter: R, Frame: 645, Probability: 0.2886922061443329
# Letter: E, Frame: 646, Probability: 0.9999568462371826
# Letter: E, Frame: 647, Probability: 0.02691987156867981
# Letter: |, Frame: 648, Probability: 0.9997439980506897
# Letter: |, Frame: 649, Probability: 2.5086010282393545e-06
# Letter: |, Frame: 650, Probability: 0.11986448615789413
# Letter: M, Frame: 651, Probability: 0.9999881982803345
# Letter: M, Frame: 652, Probability: 0.9932044744491577
# Letter: M, Frame: 653, Probability: 0.9999966621398926
# Letter: M, Frame: 654, Probability: 0.9999940395355225
# Letter: E, Frame: 655, Probability: 0.9998865127563477
# Letter: E, Frame: 656, Probability: 0.9998840093612671
# Letter: M, Frame: 657, Probability: 0.999718964099884
# Letter: M, Frame: 658, Probability: 0.48606398701667786
# Letter: M, Frame: 659, Probability: 0.9999163150787354
# Letter: O, Frame: 660, Probability: 0.9998055100440979
# Letter: R, Frame: 661, Probability: 0.998897910118103
# Letter: R, Frame: 662, Probability: 0.0022508250549435616
# Letter: R, Frame: 663, Probability: 0.9999990463256836
# Letter: R, Frame: 664, Probability: 0.9996480941772461
# Letter: A, Frame: 665, Probability: 0.9999843835830688
# Letter: A, Frame: 666, Probability: 0.9973176121711731
# Letter: B, Frame: 667, Probability: 0.9999958276748657
# Letter: B, Frame: 668, Probability: 0.9848854541778564
# Letter: B, Frame: 669, Probability: 0.9998887777328491
# Letter: L, Frame: 670, Probability: 0.9999710321426392
# Letter: L, Frame: 671, Probability: 0.00015745189739391208
# Letter: E, Frame: 672, Probability: 0.9965887069702148

# %%
# We merge repeated letters and average the probability scores
@dataclass
class Segment:
    label: str
    start: int
    end: int
    score: float

    def __repr__(self):
        return f"{self.label}\t({self.score:4.2f}): [{self.start:5d}, {self.end:5d})"

    @property
    def length(self):
        return self.end - self.start


def merge_repeats(path, transcript):
    i1, i2 = 0, 0
    segments = []
    while i1 < len(path):
        while i2 < len(path) and path[i1].token_index == path[i2].token_index:
            i2 += 1
        score = sum(path[k].score for k in range(i1, i2)) / (i2 - i1)
        segments.append(
            Segment(
                transcript[path[i1].token_index],
                path[i1].time_index,
                path[i2 - 1].time_index + 1,
                score,
            )
        )
        i1 = i2
    return segments


letter_segments = merge_repeats(path, transcript)
for seg in letter_segments:
    print(f"Letter: {seg.label}, Frame(s): {seg.start} - {seg.end}, Probability: {seg.score}")
# Out:
# Letter: B, Frame(s): 30 - 33, Probability: 0.9978779157002767
# Letter: U, Frame(s): 33 - 34, Probability: 0.999883770942688
# Letter: T, Frame(s): 34 - 36, Probability: 0.5019909022375941
# Letter: |, Frame(s): 36 - 39, Probability: 0.9998950560887655
# Letter: A, Frame(s): 39 - 41, Probability: 0.5047817998565733
# Letter: F, Frame(s): 41 - 44, Probability: 0.6813062528769175
# Letter: T, Frame(s): 44 - 46, Probability: 0.9999841451644897
# Letter: E, Frame(s): 46 - 47, Probability: 0.9999806880950928
# Letter: R, Frame(s): 47 - 50, Probability: 0.34963943806360476
# Letter: |, Frame(s): 50 - 60, Probability: 0.8055566123227663
# Letter: A, Frame(s): 60 - 61, Probability: 0.9999972581863403
# Letter: L, Frame(s): 61 - 65, Probability: 0.7504934325697832
# Letter: L, Frame(s): 65 - 67, Probability: 0.49972673904585463
# Letter: |, Frame(s): 67 - 69, Probability: 0.49966502919778577
# Letter: T, Frame(s): 69 - 71, Probability: 0.5490692183375359
# Letter: H, Frame(s): 71 - 74, Probability: 0.999919056892395
# Letter: A, Frame(s): 74 - 76, Probability: 0.5244040228426456
# Letter: T, Frame(s): 76 - 78, Probability: 0.4959520988359145
# Letter: |, Frame(s): 78 - 80, Probability: 0.9871768951416016
# Letter: C, Frame(s): 80 - 83, Probability: 0.9999905029932658
# Letter: O, Frame(s): 83 - 84, Probability: 0.9999860525131226
# Letter: M, Frame(s): 84 - 87, Probability: 0.9999790589014689
# Letter: M, Frame(s): 87 - 91, Probability: 0.9989912360906601
# Letter: O, Frame(s): 91 - 95, Probability: 0.999948263168335
# Letter: T, Frame(s): 95 - 98, Probability: 0.6673074712355932
# Letter: I, Frame(s): 98 - 101, Probability: 0.9602037469546
# Letter: O, Frame(s): 101 - 102, Probability: 0.9999808073043823
# Letter: N, Frame(s): 102 - 106, Probability: 0.6387999991589766
# Letter: |, Frame(s): 106 - 144, Probability: 0.9478786348783108
# Letter: W, Frame(s): 144 - 149, Probability: 0.7295315027236938
# Letter: A, Frame(s): 149 - 151, Probability: 0.9709994792938232
# Letter: S, Frame(s): 151 - 154, Probability: 0.6647519362203033
# Letter: |, Frame(s): 154 - 156, Probability: 0.5021401529666036
# Letter: I, Frame(s): 156 - 157, Probability: 0.999445378780365
# Letter: T, Frame(s): 157 - 158, Probability: 0.9992751479148865
# Letter: |, Frame(s): 158 - 162, Probability: 0.7500296097714454
# Letter: A, Frame(s): 162 - 163, Probability: 0.999991774559021
# Letter: L, Frame(s): 163 - 166, Probability: 0.9064708550771078
# Letter: L, Frame(s): 166 - 168, Probability: 0.6542579829692841
# Letter: |, Frame(s): 168 - 171, Probability: 0.6663289002996559
# Letter: W, Frame(s): 171 - 174, Probability: 0.9326706528663635
# Letter: O, Frame(s): 174 - 176, Probability: 0.5007637011585757
# Letter: R, Frame(s): 176 - 178, Probability: 0.9999960660934448
# Letter: T, Frame(s): 178 - 179, Probability: 0.9999803304672241
# Letter: H, Frame(s): 179 - 186, Probability: 0.5811236652163123
# Letter: W, Frame(s): 186 - 187, Probability: 0.9999635219573975
# Letter: H, Frame(s): 187 - 194, Probability: 0.9997046419552394
# Letter: I, Frame(s): 194 - 197, Probability: 0.40117641355997574
# Letter: L, Frame(s): 197 - 198, Probability: 0.9999722242355347
# Letter: E, Frame(s): 198 - 201, Probability: 0.33442356676644164
# Letter: |, Frame(s): 201 - 280, Probability: 0.9746713762681622
# Letter: A, Frame(s): 280 - 283, Probability: 0.34618286478022736
# Letter: B, Frame(s): 283 - 289, Probability: 0.8353083214412133
# Letter: S, Frame(s): 289 - 294, Probability: 0.9999279737472534
# Letter: O, Frame(s): 294 - 297, Probability: 0.9974176287651062
# Letter: L, Frame(s): 297 - 303, Probability: 0.8328393355559456
# Letter: U, Frame(s): 303 - 306, Probability: 0.6665821125886092
# Letter: T, Frame(s): 306 - 307, Probability: 0.9999136924743652
# Letter: E, Frame(s): 307 - 310, Probability: 0.9992702603340149
# Letter: L, Frame(s): 310 - 313, Probability: 0.6669113272024939
# Letter: Y, Frame(s): 313 - 316, Probability: 0.36899043156779027
# Letter: |, Frame(s): 316 - 318, Probability: 0.8031488358974457
# Letter: Y, Frame(s): 318 - 325, Probability: 0.999664809022631
# Letter: E, Frame(s): 325 - 328, Probability: 0.9876116911570231
# Letter: S, Frame(s): 328 - 331, Probability: 0.6664425306371413
# Letter: |, Frame(s): 331 - 375, Probability: 0.9473475286129346
# Letter: T, Frame(s): 375 - 376, Probability: 0.999373733997345
# Letter: H, Frame(s): 376 - 378, Probability: 0.5421677492558956
# Letter: E, Frame(s): 378 - 380, Probability: 0.5094077168032527
# Letter: |, Frame(s): 380 - 383, Probability: 0.9956551392873129
# Letter: S, Frame(s): 383 - 387, Probability: 0.9995910674333572
# Letter: E, Frame(s): 387 - 391, Probability: 0.9980093240737915
# Letter: T, Frame(s): 391 - 394, Probability: 0.4050170471891761
# Letter: |, Frame(s): 394 - 395, Probability: 0.9999350309371948
# Letter: D, Frame(s): 395 - 398, Probability: 0.6947532196839651
# Letter: E, Frame(s): 398 - 402, Probability: 0.8676944524049759
# Letter: S, Frame(s): 402 - 410, Probability: 0.9999971240758896
# Letter: I, Frame(s): 410 - 412, Probability: 0.5007430149707943
# Letter: G, Frame(s): 412 - 414, Probability: 0.5343180820345879
# Letter: N, Frame(s): 414 - 418, Probability: 0.6796788353531156
# Letter: |, Frame(s): 418 - 424, Probability: 0.8215648632234114
# Letter: W, Frame(s): 424 - 428, Probability: 0.9511815756559372
# Letter: A, Frame(s): 428 - 429, Probability: 0.9999738931655884
# Letter: S, Frame(s): 429 - 431, Probability: 0.5565442442893982
# Letter: |, Frame(s): 431 - 437, Probability: 0.66667861492309
# Letter: B, Frame(s): 437 - 441, Probability: 0.9133675694465637
# Letter: R, Frame(s): 441 - 443, Probability: 0.561347134411335
# Letter: E, Frame(s): 443 - 445, Probability: 0.6993164420127869
# Letter: A, Frame(s): 445 - 448, Probability: 0.963202714920044
# Letter: T, Frame(s): 448 - 449, Probability: 0.9998922348022461
# Letter: H, Frame(s): 449 - 453, Probability: 0.7005667313933372
# Letter: T, Frame(s): 453 - 458, Probability: 0.9998165249824524
# Letter: A, Frame(s): 458 - 461, Probability: 0.9952459931373596
# Letter: K, Frame(s): 461 - 466, Probability: 0.9999142289161682
# Letter: I, Frame(s): 466 - 467, Probability: 0.9997249245643616
# Letter: N, Frame(s): 467 - 469, Probability: 0.5080563016235828
# Letter: G, Frame(s): 469 - 472, Probability: 0.5463755905912345
# Letter: |, Frame(s): 472 - 490, Probability: 0.9370172955936545
# Letter: T, Frame(s): 490 - 491, Probability: 0.9996761083602905
# Letter: H, Frame(s): 491 - 492, Probability: 0.9998263716697693
# Letter: E, Frame(s): 492 - 495, Probability: 0.37966898844266933
# Letter: |, Frame(s): 495 - 501, Probability: 0.9655142227808634
# Letter: A, Frame(s): 501 - 502, Probability: 0.9999947547912598
# Letter: C, Frame(s): 502 - 506, Probability: 0.9946618378162384
# Letter: T, Frame(s): 506 - 510, Probability: 0.9998845010995865
# Letter: O, Frame(s): 510 - 511, Probability: 0.999562680721283
# Letter: R, Frame(s): 511 - 515, Probability: 0.6444031689316034
# Letter: S, Frame(s): 515 - 517, Probability: 0.5026762259658426
# Letter: |, Frame(s): 517 - 521, Probability: 0.6421307256572675
# Letter: W, Frame(s): 521 - 526, Probability: 0.8071608170866966
# Letter: E, Frame(s): 526 - 527, Probability: 0.9997321963310242
# Letter: R, Frame(s): 527 - 530, Probability: 0.6581941992044449
# Letter: E, Frame(s): 530 - 533, Probability: 0.5134152663170587
# Letter: |, Frame(s): 533 - 541, Probability: 0.8750075531770563
# Letter: I, Frame(s): 541 - 542, Probability: 0.9999717473983765
# Letter: N, Frame(s): 542 - 551, Probability: 0.9621189567777846
# Letter: C, Frame(s): 551 - 554, Probability: 0.997286836306254
# Letter: R, Frame(s): 554 - 558, Probability: 0.8502757549285889
# Letter: E, Frame(s): 558 - 561, Probability: 0.956279476483663
# Letter: D, Frame(s): 561 - 564, Probability: 0.975524365901947
# Letter: I, Frame(s): 564 - 567, Probability: 0.838608980178833
# Letter: B, Frame(s): 567 - 571, Probability: 0.7499093500155141
# Letter: L, Frame(s): 571 - 573, Probability: 0.894364207983017
# Letter: E, Frame(s): 573 - 575, Probability: 0.5177288129925728
# Letter: |, Frame(s): 575 - 606, Probability: 0.9551853312923706
# Letter: A, Frame(s): 606 - 607, Probability: 0.9999731779098511
# Letter: N, Frame(s): 607 - 609, Probability: 0.5351484641432762
# Letter: D, Frame(s): 609 - 611, Probability: 0.49939061375698657
# Letter: |, Frame(s): 611 - 613, Probability: 0.499991260992374
# Letter: T, Frame(s): 613 - 614, Probability: 0.9971627593040466
# Letter: H, Frame(s): 614 - 615, Probability: 0.9976112842559814
# Letter: E, Frame(s): 615 - 617, Probability: 0.5005058028036729
# Letter: |, Frame(s): 617 - 620, Probability: 0.6684268427391847
# Letter: S, Frame(s): 620 - 628, Probability: 0.8750499017187394
# Letter: O, Frame(s): 628 - 631, Probability: 0.8005800445874532
# Letter: N, Frame(s): 631 - 632, Probability: 0.9999669790267944
# Letter: G, Frame(s): 632 - 636, Probability: 0.885418027639389
# Letter: S, Frame(s): 636 - 638, Probability: 0.6503339558839798
# Letter: |, Frame(s): 638 - 641, Probability: 0.3455202570185065
# Letter: W, Frame(s): 641 - 643, Probability: 0.9998405575752258
# Letter: E, Frame(s): 643 - 644, Probability: 0.9998422861099243
# Letter: R, Frame(s): 644 - 646, Probability: 0.6443157643079758
# Letter: E, Frame(s): 646 - 648, Probability: 0.5134383589029312
# Letter: |, Frame(s): 648 - 651, Probability: 0.37320366426987067
# Letter: M, Frame(s): 651 - 655, Probability: 0.9982958436012268
# Letter: E, Frame(s): 655 - 657, Probability: 0.9998852610588074
# Letter: M, Frame(s): 657 - 660, Probability: 0.8285664220650991
# Letter: O, Frame(s): 660 - 661, Probability: 0.9998055100440979
# Letter: R, Frame(s): 661 - 665, Probability: 0.7501989689189941
# Letter: A, Frame(s): 665 - 667, Probability: 0.998650997877121
# Letter: B, Frame(s): 667 - 670, Probability: 0.9949233531951904
# Letter: L, Frame(s): 670 - 672, Probability: 0.5000642420200165
# Letter: E, Frame(s): 672 - 673, Probability: 0.9965887069702148

# %%
# Now, we merge words and average the probability scores
def merge_words(segments, separator="|"):
    words = []
    i1, i2 = 0, 0
    while i1 < len(segments):
        if i2 >= len(segments) or segments[i2].label == separator:
            if i1 != i2:
                segs = segments[i1:i2]
                word = "".join([seg.label for seg in segs])
                score = sum(seg.score * seg.length for seg in segs) / sum(seg.length for seg in segs)
                words.append(Segment(word, segments[i1].start, segments[i2 - 1].end, score))
            i1 = i2 + 1
            i2 = i1
        else:
            i2 += 1
    return words


word_segments = merge_words(letter_segments)
for word in word_segments:
    print(f"Word: {word.label}, Frame(s): {word.start} - {word.end}, Probability: {word.score}")
# Out:
# Word: BUT, Frame(s): 30 - 36, Probability: 0.8329165537531177
# Word: AFTER, Frame(s): 39 - 50, Probability: 0.6456681500871624
# Word: ALL, Frame(s): 60 - 67, Probability: 0.7144892095081689
# Word: THAT, Frame(s): 69 - 78, Probability: 0.6820675389677086
# Word: COMMOTION, Frame(s): 80 - 106, Probability: 0.9012833536055452
# Word: WAS, Frame(s): 144 - 154, Probability: 0.7583912280867026
# Word: IT, Frame(s): 156 - 158, Probability: 0.9993602633476257
# Word: ALL, Frame(s): 162 - 168, Probability: 0.8379867176214854
# Word: WORTHWHILE, Frame(s): 171 - 201, Probability: 0.7357348553647801
# Word: ABSOLUTELY, Frame(s): 280 - 316, Probability: 0.7817917605252309
# Word: YES, Frame(s): 318 - 331, Probability: 0.9199858714262239
# Word: THE, Frame(s): 375 - 380, Probability: 0.6205049332231283
# Word: SET, Frame(s): 383 - 394, Probability: 0.836859337054193
# Word: DESIGN, Frame(s): 395 - 418, Probability: 0.7975587824653105
# Word: WAS, Frame(s): 424 - 431, Probability: 0.8453983834811619
# Word: BREATHTAKING, Frame(s): 437 - 472, Probability: 0.8430263081217325
# Word: THE, Frame(s): 490 - 495, Probability: 0.6277018890716135
# Word: ACTORS, Frame(s): 501 - 517, Probability: 0.8475442449271213
# Word: WERE, Frame(s): 521 - 533, Probability: 0.7125303898607515
# Word: INCREDIBLE, Frame(s): 541 - 575, Probability: 0.88785493519818
# Word: AND, Frame(s): 606 - 611, Probability: 0.6138102667420753
# Word: THE, Frame(s): 613 - 617, Probability: 0.7489464122918434
# Word: SONGS, Frame(s): 620 - 638, Probability: 0.8469136860480325
# Word: WERE, Frame(s): 641 - 648, Probability: 0.75929023538317
# Word: MEMORABLE, Frame(s): 651 - 673, Probability: 0.8844565361267253

# %%
# If we wanted forced alignment of letters or words, we would be done. However, we want forced alignment of phonemes, so we need to convert the letters to phonemes.
# We make use of the CMU grapheme 2 phoneme alignment dictionary (aligned using Phonetisaurus) hosted here: https://github.com/ckw017/aligned-cmudict/blob/master/g2p.json

# Let's clean up the g2p dictionary a bit and make sure it's using the Sphinx 40 Phoneme set.
g2p_path = "./cmudict/g2p.json"
import json
import re
with open(g2p_path, "r") as f:
    g2p = json.load(f)

to_remove = []

unique_phonemes = set()
for key in g2p:
    if not any("foreign" in element for element in g2p[key]['phonemes']) and not any("#" in element for element in g2p[key]['phonemes']) and not any("old" in element for element in g2p[key]['phonemes']):
      for phoneme in g2p[key]['phonemes']:
        for individual_phoneme in phoneme.split('|'):
            unique_phonemes.add(re.sub(r'\d+', '', individual_phoneme))
    else:
      to_remove.append(key)

for key in to_remove:
    del g2p[key]

# Read CMU Phonemes into a list

CMU_phonemes_path = "./cmudict/SphinxPhones_40.txt"
CMU_phonemes = set()
with open(CMU_phonemes_path, "r") as f:
    for line in f:
        CMU_phonemes.add(line.strip())

print(f"The following phonemes are in CMU but not in g2p: {CMU_phonemes.difference(unique_phonemes)}")
print(f"The following phonemes are in g2p but not in CMU: {unique_phonemes.difference(CMU_phonemes)}")

# Note that 'SIL' and '_' refer to blank phonemes.

print(f"The word 'hello' in g2p looks like {g2p['hello']}")
print(f"The word 'memorable' in g2p looks like {g2p['memorable']}")
# Out:
# The following phonemes are in CMU but not in g2p: {'SIL'}
# The following phonemes are in g2p but not in CMU: {'_'}
# The word 'hello' in g2p looks like {'graphemes': ['h', 'e', 'l|l', 'o'], 'phonemes': ['HH', 'EH0', 'L', 'OW1']}
# The word 'memorable' in g2p looks like {'graphemes': ['m', 'e', 'm', 'o|r', 'a', 'b', 'l', 'e'], 'phonemes': ['M', 'EH1', 'M', 'ER0', 'AH0', 'B', 'AH0|L', '_']}

# %%
# Converting from graphemes to phonemes is not trivial because it is not a one-to-one mapping (it is many-to-many). For example, the word "hello" has 5 letters but 4 phonemes. In the word "memorable", the letter "l" maps to 2 phonemes - AH and L.
# This algorithm merges the letters aligned using the CTC algorithm into phonemes using the g2p dictionary. It also adds phoneme separators between phonemes and word separators between words. Using this algorithm in production require lots of testing.

def find_phonemes(letter_segments, word_segments, g2p):
    # This function will modify letter_segments, so make a copy if you'd like to keep the original
    segment_index = 0
    letter_segments.append(Segment("|", letter_segments[-1].end, letter_segments[-1].end, 1.0)) # add a word separator at the end of the transcript
    for word in word_segments:
        # print(f"Scanning word {word.label}")
        phonemes_map = g2p[word.label.lower()]
        for idx, grapheme in enumerate(phonemes_map['graphemes']):
            if "|" not in grapheme:
                if grapheme != letter_segments[segment_index].label.lower():
                    # print(f"Error: {grapheme} != {letter_segments[segment_index].label}")
                    break
                letter_segments[segment_index].label = phonemes_map['phonemes'][idx]
                segment_index += 1

                if letter_segments[segment_index].label == "|":
                    # print(f"Found word separator after {word.label}")
                    segment_index += 1
                else:
                    # print(f"Adding phoneme separator after {letter_segments[segment_index-1].label}")
                    letter_segments.insert(segment_index, Segment("|", letter_segments[segment_index-1].end, letter_segments[segment_index].start, 1.0))
                    segment_index += 1
            else:
                # print(f"Found 2 letter phoneme {grapheme}")
                for idx2, letter in enumerate(grapheme.split("|")):               
                    letter_segments[segment_index].label = phonemes_map['phonemes'][idx]
                    # print(f"Letter {idx2}: {letter}. Segment: {letter_segments[segment_index].label}")
                    segment_index += 1
                if letter_segments[segment_index].label != "|":
                    # print(f"Adding phoneme separator after {letter_segments[segment_index-1].label}")
                    letter_segments.insert(segment_index, Segment("|", letter_segments[segment_index-1].end, letter_segments[segment_index].start, 1.0))
                    segment_index += 1
                else:
                    # print(f"Found word separator after {word.label}")
                    segment_index += 1

    # remove silent phonemes
    phoneme_segments = [segment for segment in letter_segments if segment.label != "_"]

    # mitigate double phonemes by splitting them evenly in time, this is an approximation which introduces small errors
    split_segments = []
    import numpy as np
    for segment in phoneme_segments:
        if segment.label == "|":
            split_segments.append(segment)
            continue
        phonemes = segment.label.split("|")
        num_parts = len(phonemes)
        if num_parts > 1:
            # print(f"Found {num_parts} phonemes in {segment.label}")
            parts = np.linspace(segment.start, segment.end, num_parts + 1, dtype=int)
            for idx, phoneme in enumerate(phonemes):
                split_segments.append(Segment(phoneme, parts[idx], parts[idx+1], segment.score))
                split_segments.append(Segment("|", parts[idx+1], parts[idx+1], 1.0))
        else:
            split_segments.append(segment)

    while split_segments[-1].label == "|":
        # print(f"Removing trailing word separator at {split_segments[-1].start}")
        split_segments = split_segments[:-1] # remove last "|" segment
    return split_segments

# Merge phonemes
def merge_repeat_phonemes(segments, separator="|"):
    # segments = phoneme_segments[:]
    phonemes = []
    i1, i2 = 0, 0
    while i1 < len(segments):
        if i2 >= len(segments) or segments[i2].label == separator:
            if i1 != i2:
                segs = segments[i1:i2]
                if all(seg.label == segs[0].label for seg in segs):
                    phoneme = segs[0].label
                else:
                    phoneme = "".join([seg.label for seg in segs])
                score = sum(seg.score * seg.length for seg in segs) / sum(seg.length for seg in segs)
                phonemes.append(Segment(phoneme, segments[i1].start, segments[i2 - 1].end, score))
            i1 = i2 + 1
            i2 = i1
        else:
            i2 += 1
    return phonemes

letter_segments_copy = copy.deepcopy(letter_segments) # find_phonemes will modify letter_segments, so make a copy if you'd like to keep the original
phoneme_segments = find_phonemes(letter_segments_copy, word_segments, g2p)
phoneme_segments = merge_repeat_phonemes(phoneme_segments)

ratio = waveform.size()[1] / (trellis.size(0) - 1)
for phoneme in phoneme_segments:
    phoneme.label = re.sub(r'\d', '', phoneme.label) # we can remove the stress markers, but keep in mind they may be useful for future work
    phoneme.start = ratio * phoneme.start / sample_rate # convert to seconds
    phoneme.end = ratio * phoneme.end / sample_rate
    print(f"Phoneme: {phoneme.label}, Time: {phoneme.start:.3f}s - {phoneme.end:.3f}s")

# Save phonemes to JSON
output_file = "output/method_1.json"
save_phonemes_JSON(phoneme_segments, output_file)
# Out:
# Phoneme: B, Time: 0.600s - 0.661s
# Phoneme: AH, Time: 0.661s - 0.681s
# Phoneme: T, Time: 0.681s - 0.721s
# Phoneme: AE, Time: 0.781s - 0.821s
# Phoneme: F, Time: 0.821s - 0.881s
# Phoneme: T, Time: 0.881s - 0.921s
# Phoneme: ER, Time: 0.921s - 1.001s
# Phoneme: AO, Time: 1.201s - 1.221s
# Phoneme: L, Time: 1.221s - 1.341s
# Phoneme: DH, Time: 1.381s - 1.481s
# Phoneme: AH, Time: 1.481s - 1.521s
# Phoneme: T, Time: 1.521s - 1.561s
# Phoneme: K, Time: 1.601s - 1.661s
# Phoneme: AH, Time: 1.661s - 1.681s
# Phoneme: M, Time: 1.681s - 1.821s
# Phoneme: OW, Time: 1.821s - 1.902s
# Phoneme: SH, Time: 1.902s - 2.022s
# Phoneme: AH, Time: 2.022s - 2.042s
# Phoneme: N, Time: 2.042s - 2.122s
# Phoneme: W, Time: 2.882s - 2.982s
# Phoneme: AH, Time: 2.982s - 3.022s
# Phoneme: Z, Time: 3.022s - 3.082s
# Phoneme: IH, Time: 3.122s - 3.142s
# Phoneme: T, Time: 3.142s - 3.163s
# Phoneme: AO, Time: 3.243s - 3.263s
# Phoneme: L, Time: 3.263s - 3.363s
# Phoneme: W, Time: 3.423s - 3.483s
# Phoneme: ER, Time: 3.483s - 3.563s
# Phoneme: TH, Time: 3.563s - 3.723s
# Phoneme: W, Time: 3.723s - 3.743s
# Phoneme: AY, Time: 3.883s - 3.943s
# Phoneme: L, Time: 3.943s - 3.963s
# Phoneme: AE, Time: 5.604s - 5.664s
# Phoneme: B, Time: 5.664s - 5.785s
# Phoneme: S, Time: 5.785s - 5.885s
# Phoneme: AH, Time: 5.885s - 5.945s
# Phoneme: L, Time: 5.945s - 6.065s
# Phoneme: UW, Time: 6.065s - 6.125s
# Phoneme: T, Time: 6.125s - 6.145s
# Phoneme: L, Time: 6.205s - 6.265s
# Phoneme: IY, Time: 6.265s - 6.325s
# Phoneme: Y, Time: 6.365s - 6.505s
# Phoneme: EH, Time: 6.505s - 6.565s
# Phoneme: S, Time: 6.565s - 6.625s
# Phoneme: DH, Time: 7.506s - 7.566s
# Phoneme: IY, Time: 7.566s - 7.606s
# Phoneme: S, Time: 7.666s - 7.746s
# Phoneme: EH, Time: 7.746s - 7.826s
# Phoneme: T, Time: 7.826s - 7.886s
# Phoneme: D, Time: 7.906s - 7.966s
# Phoneme: IH, Time: 7.966s - 8.046s
# Phoneme: Z, Time: 8.046s - 8.207s
# Phoneme: AY, Time: 8.207s - 8.247s
# Phoneme: N, Time: 8.287s - 8.367s
# Phoneme: W, Time: 8.487s - 8.567s
# Phoneme: AH, Time: 8.567s - 8.587s
# Phoneme: Z, Time: 8.587s - 8.627s
# Phoneme: B, Time: 8.747s - 8.827s
# Phoneme: R, Time: 8.827s - 8.867s
# Phoneme: EH, Time: 8.907s - 8.967s
# Phoneme: TH, Time: 8.967s - 9.067s
# Phoneme: T, Time: 9.067s - 9.167s
# Phoneme: EY, Time: 9.167s - 9.227s
# Phoneme: K, Time: 9.227s - 9.327s
# Phoneme: IH, Time: 9.327s - 9.347s
# Phoneme: NG, Time: 9.347s - 9.447s
# Phoneme: DH, Time: 9.808s - 9.848s
# Phoneme: IY, Time: 9.848s - 9.908s
# Phoneme: AE, Time: 10.028s - 10.048s
# Phoneme: K, Time: 10.048s - 10.128s
# Phoneme: T, Time: 10.128s - 10.208s
# Phoneme: ER, Time: 10.208s - 10.308s
# Phoneme: Z, Time: 10.308s - 10.348s
# Phoneme: W, Time: 10.428s - 10.528s
# Phoneme: ER, Time: 10.528s - 10.608s
# Phoneme: IH, Time: 10.829s - 10.849s
# Phoneme: N, Time: 10.849s - 11.029s
# Phoneme: K, Time: 11.029s - 11.089s
# Phoneme: R, Time: 11.089s - 11.169s
# Phoneme: EH, Time: 11.169s - 11.229s
# Phoneme: D, Time: 11.229s - 11.289s
# Phoneme: AH, Time: 11.289s - 11.349s
# Phoneme: B, Time: 11.349s - 11.429s
# Phoneme: AH, Time: 11.429s - 11.449s
# Phoneme: L, Time: 11.449s - 11.469s
# Phoneme: AE, Time: 12.130s - 12.150s
# Phoneme: N, Time: 12.150s - 12.190s
# Phoneme: D, Time: 12.190s - 12.230s
# Phoneme: DH, Time: 12.270s - 12.310s
# Phoneme: IY, Time: 12.310s - 12.350s
# Phoneme: S, Time: 12.410s - 12.570s
# Phoneme: AO, Time: 12.570s - 12.630s
# Phoneme: NG, Time: 12.630s - 12.730s
# Phoneme: Z, Time: 12.730s - 12.770s
# Phoneme: W, Time: 12.830s - 12.870s
# Phoneme: ER, Time: 12.870s - 12.930s
# Phoneme: M, Time: 13.030s - 13.110s
# Phoneme: EH, Time: 13.110s - 13.150s
# Phoneme: M, Time: 13.150s - 13.210s
# Phoneme: ER, Time: 13.210s - 13.311s
# Phoneme: AH, Time: 13.311s - 13.351s
# Phoneme: B, Time: 13.351s - 13.411s
# Phoneme: AH, Time: 13.411s - 13.431s
# Phoneme: L, Time: 13.431s - 13.451s

# %%
# Play the first 10 phonemes

for i in range(10):
    display_segment(phoneme_segments, i, waveform, sample_rate)
# Out:
# B (1.00): 0.600 - 0.661 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AH (1.00): 0.661 - 0.681 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# T (0.50): 0.681 - 0.721 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AE (0.50): 0.781 - 0.821 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# F (0.68): 0.821 - 0.881 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# T (1.00): 0.881 - 0.921 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ER (0.51): 0.921 - 1.001 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AO (1.00): 1.201 - 1.221 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# L (0.67): 1.221 - 1.341 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# DH (0.82): 1.381 - 1.481 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Method 2: CTC Segmentation using wav2vec2-large-english-phoneme-v2
#
# Rather than convert between graphemes and phonemes, it may be better to use an ASR model pre-trained to identify English phonemes.
# There is one available at https://huggingface.co/speech31/wav2vec2-large-english-phoneme-v2 but it doesn't use the ARPABET phoneme set.

# %%
# Load the pretrained phoneme recognition model
# Clone the repo from https://huggingface.co/speech31/wav2vec2-large-english-phoneme-v2/tree/main

letters_dictionary = json.load(open("./wav2vec2-large-english-phoneme-v2/vocab.json"))
tokenizer = Wav2Vec2CTCTokenizer("./wav2vec2-large-english-phoneme-v2/vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")
feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)
processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)
model = Wav2Vec2ForCTC.from_pretrained("./wav2vec2-large-english-phoneme-v2")

# %%
# Run inference on sample audio file
model.to(device)
input_values = processor(waveform.squeeze(), sampling_rate=sample_rate, return_tensors="pt").input_values.to(device)

with torch.no_grad():
  emissions = model(input_values).logits
emission = emissions[0].cpu().detach()

# We only need the emissions to perform forced alignment, but we can print the transcript generate by the ASR model if we want.
pred_ids = torch.argmax(emissions, dim=-1)
print(f"Letters: {' '.join(processor.tokenizer.convert_ids_to_tokens(pred_ids[0].tolist()))}")
pred_str = processor.batch_decode(pred_ids)[0]
print(f"ASR Model Transcript (CTC Decoded): {pred_str}")
# Out:
# Letters: [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] b ə ə t | | ˈ ˈ [PAD] æ [PAD] f f t t t ə ə r r r | | | [PAD] [PAD] [PAD] ɔ ɔ ɔ l l l l l l | | | ð ð [PAD] ə [PAD] [PAD] [PAD] t | | [PAD] k [PAD] ə ə ˈ ˈ m m [PAD] o o ʊ ʊ [PAD] [PAD] [PAD] ʃ ʃ [PAD] [PAD] ə ə n n [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] | | | [PAD] [PAD] w w w ɑ ɑ [PAD] z z z | ɪ ɪ t | | [PAD] ɔ ɔ ɔ l l l l | | | [PAD] w w [PAD] ə ə r r [PAD] [PAD] θ θ | | | [PAD] w w w a a a a ɪ ɪ ɪ [PAD] l l l [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] ˈ ˈ ˈ [PAD] [PAD] æ æ [PAD] [PAD] [PAD] b b b [PAD] [PAD] [PAD] s s [PAD] [PAD] ə ə ə [PAD] [PAD] l l l [PAD] u u n n t t t l l l [PAD] i i | | | [PAD] j [PAD] [PAD] [PAD] ɛ [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] s s s [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] ə ə | | [PAD] s s s [PAD] [PAD] [PAD] [PAD] ɛ [PAD] [PAD] t t | d d d ɪ ɪ ˈ z z [PAD] [PAD] [PAD] [PAD] a a a ɪ ɪ ɪ ɪ [PAD] [PAD] n n [PAD] [PAD] [PAD] | | | [PAD] w w ɑ ɑ [PAD] z z [PAD] | | | ˈ ˈ b b b r r r r ə [PAD] [PAD] [PAD] θ θ [PAD] [PAD] ˈ [PAD] t [PAD] [PAD] e ɪ ɪ [PAD] [PAD] k [PAD] [PAD] [PAD] [PAD] ɪ ɪ ŋ ŋ [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] | | | | ð ð ə ə | | | | ˈ ˈ [PAD] æ [PAD] [PAD] k k [PAD] t t ə ə r r r r [PAD] z z | | | [PAD] [PAD] w w w ə ə ə r r r r [PAD] [PAD] | | | | [PAD] [PAD] [PAD] ɪ ɪ n n [PAD] ˈ ˈ ˈ k k k [PAD] r r r [PAD] ɛ [PAD] [PAD] t t [PAD] ə ə ə [PAD] b b [PAD] ə ə l l l [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] | | | | [PAD] [PAD] [PAD] ə ə [PAD] n n d d | | ð ə ə | | [PAD] s s [PAD] [PAD] [PAD] [PAD] o ʊ ʊ [PAD] [PAD] [PAD] [PAD] m m [PAD] [PAD] [PAD] z [PAD] | [PAD] w w ə r r r | | ˈ ˈ m m [PAD] ɛ [PAD] [PAD] m [PAD] ə ə r r r ə ə [PAD] b b [PAD] ə l l l [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] | |
# ASR Model Transcript (CTC Decoded): bət ˈæftər ɔl ðət kəˈmoʊʃən wɑz ɪt ɔl wərθ waɪlˈæbsəluntli jɛsə sɛt dɪˈzaɪn wɑz ˈbrəθˈteɪkɪŋ ðə ˈæktərz wər ɪnˈkrɛtəbəl ənd ðə soʊmz wər ˈmɛmərəbəl

# %%
# The phonemes used by this pre-trained model are close, but not identical to the CMU Sphinx phonemes. I did my best to map them but it would be smarter to fine tune a model on the Sphinx phonemes.

sphinx_to_ipa = {
  "'": "'",
  "[PAD]": "[PAD]",
  "[UNK]": "[UNK]",
  "AY": "aɪ",
  "B": "b",
  "C": "c",
  "D": "d",
  "EY": "e",
  "F": "f",
  "G": "g",
  "HH": "h",
  "IY": "i",
  "ZH": "ʒ",
  "K": "k",
  "L": "l",
  "M": "m",
  "N": "n",
  "AW": "o",
  "OW": "oʊ",
  "P": "p",
  "Q": "q",
  "R": "r",
  "S": "s",
  "T": "t",
  "UW": "u",
  "V": "v",
  "W": "w",
  "Y": "y",
  "Z": "z",
  "|": "|",
  "AE": "æ",
  "DH": "ð",
  "NG": "ŋ",
  "AA": "ɑ",
  "AO": "ɔ",
  "AH": "ə",
  "EH": "ɛ",
  "IH": "ɪ",
  "SH": "ʃ",
  "UH": "ʊ",
  "JH": "ʤ",
  "CH": "ʧ",
  "'": "ˈ",
  "TH": "θ",
  "ER": "ər", # pretrained model has no ɝ
  "OY": "ɔɪ"
}

# %%
# Now, we convert the ground truth transcript to IPA

# First, convert the CMU dictionary to IPA
CMU = CMUDict(root='./cmudict', download=True)

CMU_dict = {}
for word in CMU:
	if word[0] == 'THE':
		CMU_dict['the'] = 'ðə' # Choose the other pronunciation of "the" to generate the correct IPA transcript for the test example
	else:
		CMU_dict[word[0].lower()] = [sphinx_to_ipa[re.sub(r'\d', '', phoneme.upper())] for phoneme in word[1]] # strip out stress markers

print(f"Hello: {CMU_dict['hello']}")

ipa_transcript = [] # transcript in modified IPA
for word in transcript.split('|'):
  ipa_transcript += CMU_dict[word.lower()]
  ipa_transcript += ['|']

print(f"IPA Transcript: {''.join(ipa_transcript)}")
# Out:
# Hello: ['h', 'ɛ', 'l', 'oʊ']
# IPA Transcript: bət|æftər|ɔl|ðət|kəmoʊʃən|wɑz|ɪt|ɔl|wərθwaɪl|æbsəlutli|yɛs|ðə|sɛt|dɪzaɪn|wɑz|brɛθtekɪŋ|ðə|æktərz|wər|ɪnkrɛdəbəl|ænd|ðə|sɔŋz|wər|mɛmərəbəl|

# %%
# Next, we proceed as in method 1 using the CTC algorithm to find the most likely alignment timestamps between the wav2vec2 output and the ground truth transcript.
with open("./wav2vec2-large-english-phoneme-v2/vocab.json", 'r', encoding='utf-8') as file:
    letters_dictionary = json.load(file)

tokens = [letters_dictionary[c] for c in ''.join(ipa_transcript)]
# print(tokens)
trellis = get_trellis(emission, tokens)
# print(trellis.shape)

path = backtrack(trellis, emission, tokens)
phoneme_segments = merge_repeats(path, ''.join(ipa_transcript))
phoneme_segments = [segment for segment in phoneme_segments if segment.label != "|"]

ratio = waveform.size()[1] / (trellis.size(0) - 1)
for phoneme in phoneme_segments:
    phoneme.start = ratio * phoneme.start / sample_rate # convert to seconds
    phoneme.end = ratio * phoneme.end / sample_rate
    print(f"Phoneme: {phoneme.label}, Time: {phoneme.start:.3f}s - {phoneme.end:.3f}s")
# Out:
# Phoneme: b, Time: 0.600s - 0.620s
# Phoneme: ə, Time: 0.620s - 0.661s
# Phoneme: t, Time: 0.661s - 0.701s
# Phoneme: æ, Time: 0.781s - 0.841s
# Phoneme: f, Time: 0.841s - 0.881s
# Phoneme: t, Time: 0.881s - 0.901s
# Phoneme: ə, Time: 0.901s - 0.981s
# Phoneme: r, Time: 0.981s - 1.061s
# Phoneme: ɔ, Time: 1.161s - 1.301s
# Phoneme: l, Time: 1.301s - 1.321s
# Phoneme: ð, Time: 1.381s - 1.401s
# Phoneme: ə, Time: 1.401s - 1.521s
# Phoneme: t, Time: 1.521s - 1.541s
# Phoneme: k, Time: 1.601s - 1.621s
# Phoneme: ə, Time: 1.621s - 1.741s
# Phoneme: m, Time: 1.741s - 1.801s
# Phoneme: o, Time: 1.801s - 1.821s
# Phoneme: ʊ, Time: 1.821s - 1.922s
# Phoneme: ʃ, Time: 1.922s - 1.942s
# Phoneme: ə, Time: 1.942s - 2.062s
# Phoneme: n, Time: 2.062s - 2.822s
# Phoneme: w, Time: 2.922s - 2.942s
# Phoneme: ɑ, Time: 2.942s - 3.022s
# Phoneme: z, Time: 3.022s - 3.062s
# Phoneme: ɪ, Time: 3.102s - 3.122s
# Phoneme: t, Time: 3.122s - 3.142s
# Phoneme: ɔ, Time: 3.223s - 3.323s
# Phoneme: l, Time: 3.323s - 3.383s
# Phoneme: w, Time: 3.443s - 3.463s
# Phoneme: ə, Time: 3.463s - 3.543s
# Phoneme: r, Time: 3.543s - 3.603s
# Phoneme: θ, Time: 3.603s - 3.743s
# Phoneme: w, Time: 3.743s - 3.843s
# Phoneme: a, Time: 3.843s - 3.863s
# Phoneme: ɪ, Time: 3.863s - 3.983s
# Phoneme: l, Time: 3.983s - 5.324s
# Phoneme: æ, Time: 5.564s - 5.685s
# Phoneme: b, Time: 5.685s - 5.785s
# Phoneme: s, Time: 5.785s - 5.805s
# Phoneme: ə, Time: 5.805s - 5.985s
# Phoneme: l, Time: 5.985s - 6.045s
# Phoneme: u, Time: 6.045s - 6.165s
# Phoneme: t, Time: 6.165s - 6.225s
# Phoneme: l, Time: 6.225s - 6.265s
# Phoneme: i, Time: 6.265s - 6.305s
# Phoneme: y, Time: 6.365s - 6.465s
# Phoneme: ɛ, Time: 6.465s - 6.605s
# Phoneme: s, Time: 6.605s - 7.246s
# Phoneme: ð, Time: 7.486s - 7.506s
# Phoneme: ə, Time: 7.506s - 7.586s
# Phoneme: s, Time: 7.646s - 7.766s
# Phoneme: ɛ, Time: 7.766s - 7.846s
# Phoneme: t, Time: 7.846s - 7.866s
# Phoneme: d, Time: 7.906s - 7.946s
# Phoneme: ɪ, Time: 7.946s - 8.026s
# Phoneme: z, Time: 8.026s - 8.166s
# Phoneme: a, Time: 8.166s - 8.207s
# Phoneme: ɪ, Time: 8.207s - 8.307s
# Phoneme: n, Time: 8.307s - 8.447s
# Phoneme: w, Time: 8.507s - 8.527s
# Phoneme: ɑ, Time: 8.527s - 8.587s
# Phoneme: z, Time: 8.587s - 8.647s
# Phoneme: b, Time: 8.747s - 8.827s
# Phoneme: r, Time: 8.827s - 8.967s
# Phoneme: ɛ, Time: 8.967s - 8.987s
# Phoneme: θ, Time: 8.987s - 9.087s
# Phoneme: t, Time: 9.087s - 9.147s
# Phoneme: e, Time: 9.147s - 9.247s
# Phoneme: k, Time: 9.247s - 9.367s
# Phoneme: ɪ, Time: 9.367s - 9.387s
# Phoneme: ŋ, Time: 9.387s - 9.728s
# Phoneme: ð, Time: 9.808s - 9.828s
# Phoneme: ə, Time: 9.828s - 9.908s
# Phoneme: æ, Time: 10.008s - 10.068s
# Phoneme: k, Time: 10.068s - 10.128s
# Phoneme: t, Time: 10.128s - 10.148s
# Phoneme: ə, Time: 10.148s - 10.248s
# Phoneme: r, Time: 10.248s - 10.308s
# Phoneme: z, Time: 10.308s - 10.388s
# Phoneme: w, Time: 10.468s - 10.488s
# Phoneme: ə, Time: 10.488s - 10.608s
# Phoneme: r, Time: 10.608s - 10.749s
# Phoneme: ɪ, Time: 10.849s - 10.869s
# Phoneme: n, Time: 10.869s - 11.009s
# Phoneme: k, Time: 11.009s - 11.089s
# Phoneme: r, Time: 11.089s - 11.169s
# Phoneme: ɛ, Time: 11.169s - 11.229s
# Phoneme: d, Time: 11.229s - 11.249s
# Phoneme: ə, Time: 11.249s - 11.349s
# Phoneme: b, Time: 11.349s - 11.369s
# Phoneme: ə, Time: 11.369s - 11.489s
# Phoneme: l, Time: 11.489s - 11.990s
# Phoneme: æ, Time: 12.010s - 12.170s
# Phoneme: n, Time: 12.170s - 12.190s
# Phoneme: d, Time: 12.190s - 12.230s
# Phoneme: ð, Time: 12.270s - 12.290s
# Phoneme: ə, Time: 12.290s - 12.350s
# Phoneme: s, Time: 12.390s - 12.490s
# Phoneme: ɔ, Time: 12.490s - 12.650s
# Phoneme: ŋ, Time: 12.650s - 12.750s
# Phoneme: z, Time: 12.750s - 12.790s
# Phoneme: w, Time: 12.850s - 12.870s
# Phoneme: ə, Time: 12.870s - 12.930s
# Phoneme: r, Time: 12.930s - 12.950s
# Phoneme: m, Time: 13.030s - 13.070s
# Phoneme: ɛ, Time: 13.070s - 13.150s
# Phoneme: m, Time: 13.150s - 13.170s
# Phoneme: ə, Time: 13.170s - 13.251s
# Phoneme: r, Time: 13.251s - 13.271s
# Phoneme: ə, Time: 13.271s - 13.351s
# Phoneme: b, Time: 13.351s - 13.371s
# Phoneme: ə, Time: 13.371s - 13.471s
# Phoneme: l, Time: 13.471s - 13.491s

# %%
# Convert the phonemes to Arpabet

ipa_to_sphinx = {v: k for k, v in sphinx_to_ipa.items()}
index = 0
for grapheme in [letter for letter in ipa_transcript if letter != '|']:
    if len(grapheme) == 1:
        phoneme_segments[index].label = ipa_to_sphinx[grapheme]
        index += 1
    else:
        length = len(grapheme)
        phoneme_segments[index].label = ipa_to_sphinx[grapheme]
        phoneme_segments[index].end = phoneme_segments[index + length - 1].end
        del phoneme_segments[index + 1:index + length]
        index += 1

for phoneme in phoneme_segments:
    print(f"Phoneme: {phoneme.label}, Time: {phoneme.start:.3f}s - {phoneme.end:.3f}s")

# Save phonemes to JSON
output_file = "output/method_2.json"
save_phonemes_JSON(phoneme_segments, output_file)
# Out:
# Phoneme: B, Time: 0.600s - 0.620s
# Phoneme: AH, Time: 0.620s - 0.661s
# Phoneme: T, Time: 0.661s - 0.701s
# Phoneme: AE, Time: 0.781s - 0.841s
# Phoneme: F, Time: 0.841s - 0.881s
# Phoneme: T, Time: 0.881s - 0.901s
# Phoneme: ER, Time: 0.901s - 1.061s
# Phoneme: AO, Time: 1.161s - 1.301s
# Phoneme: L, Time: 1.301s - 1.321s
# Phoneme: DH, Time: 1.381s - 1.401s
# Phoneme: AH, Time: 1.401s - 1.521s
# Phoneme: T, Time: 1.521s - 1.541s
# Phoneme: K, Time: 1.601s - 1.621s
# Phoneme: AH, Time: 1.621s - 1.741s
# Phoneme: M, Time: 1.741s - 1.801s
# Phoneme: OW, Time: 1.801s - 1.922s
# Phoneme: SH, Time: 1.922s - 1.942s
# Phoneme: AH, Time: 1.942s - 2.062s
# Phoneme: N, Time: 2.062s - 2.822s
# Phoneme: W, Time: 2.922s - 2.942s
# Phoneme: AA, Time: 2.942s - 3.022s
# Phoneme: Z, Time: 3.022s - 3.062s
# Phoneme: IH, Time: 3.102s - 3.122s
# Phoneme: T, Time: 3.122s - 3.142s
# Phoneme: AO, Time: 3.223s - 3.323s
# Phoneme: L, Time: 3.323s - 3.383s
# Phoneme: W, Time: 3.443s - 3.463s
# Phoneme: ER, Time: 3.463s - 3.603s
# Phoneme: TH, Time: 3.603s - 3.743s
# Phoneme: W, Time: 3.743s - 3.843s
# Phoneme: AY, Time: 3.843s - 3.983s
# Phoneme: L, Time: 3.983s - 5.324s
# Phoneme: AE, Time: 5.564s - 5.685s
# Phoneme: B, Time: 5.685s - 5.785s
# Phoneme: S, Time: 5.785s - 5.805s
# Phoneme: AH, Time: 5.805s - 5.985s
# Phoneme: L, Time: 5.985s - 6.045s
# Phoneme: UW, Time: 6.045s - 6.165s
# Phoneme: T, Time: 6.165s - 6.225s
# Phoneme: L, Time: 6.225s - 6.265s
# Phoneme: IY, Time: 6.265s - 6.305s
# Phoneme: Y, Time: 6.365s - 6.465s
# Phoneme: EH, Time: 6.465s - 6.605s
# Phoneme: S, Time: 6.605s - 7.246s
# Phoneme: DH, Time: 7.486s - 7.506s
# Phoneme: AH, Time: 7.506s - 7.586s
# Phoneme: S, Time: 7.646s - 7.766s
# Phoneme: EH, Time: 7.766s - 7.846s
# Phoneme: T, Time: 7.846s - 7.866s
# Phoneme: D, Time: 7.906s - 7.946s
# Phoneme: IH, Time: 7.946s - 8.026s
# Phoneme: Z, Time: 8.026s - 8.166s
# Phoneme: AY, Time: 8.166s - 8.307s
# Phoneme: N, Time: 8.307s - 8.447s
# Phoneme: W, Time: 8.507s - 8.527s
# Phoneme: AA, Time: 8.527s - 8.587s
# Phoneme: Z, Time: 8.587s - 8.647s
# Phoneme: B, Time: 8.747s - 8.827s
# Phoneme: R, Time: 8.827s - 8.967s
# Phoneme: EH, Time: 8.967s - 8.987s
# Phoneme: TH, Time: 8.987s - 9.087s
# Phoneme: T, Time: 9.087s - 9.147s
# Phoneme: EY, Time: 9.147s - 9.247s
# Phoneme: K, Time: 9.247s - 9.367s
# Phoneme: IH, Time: 9.367s - 9.387s
# Phoneme: NG, Time: 9.387s - 9.728s
# Phoneme: DH, Time: 9.808s - 9.828s
# Phoneme: AH, Time: 9.828s - 9.908s
# Phoneme: AE, Time: 10.008s - 10.068s
# Phoneme: K, Time: 10.068s - 10.128s
# Phoneme: T, Time: 10.128s - 10.148s
# Phoneme: ER, Time: 10.148s - 10.308s
# Phoneme: Z, Time: 10.308s - 10.388s
# Phoneme: W, Time: 10.468s - 10.488s
# Phoneme: ER, Time: 10.488s - 10.749s
# Phoneme: IH, Time: 10.849s - 10.869s
# Phoneme: N, Time: 10.869s - 11.009s
# Phoneme: K, Time: 11.009s - 11.089s
# Phoneme: R, Time: 11.089s - 11.169s
# Phoneme: EH, Time: 11.169s - 11.229s
# Phoneme: D, Time: 11.229s - 11.249s
# Phoneme: AH, Time: 11.249s - 11.349s
# Phoneme: B, Time: 11.349s - 11.369s
# Phoneme: AH, Time: 11.369s - 11.489s
# Phoneme: L, Time: 11.489s - 11.990s
# Phoneme: AE, Time: 12.010s - 12.170s
# Phoneme: N, Time: 12.170s - 12.190s
# Phoneme: D, Time: 12.190s - 12.230s
# Phoneme: DH, Time: 12.270s - 12.290s
# Phoneme: AH, Time: 12.290s - 12.350s
# Phoneme: S, Time: 12.390s - 12.490s
# Phoneme: AO, Time: 12.490s - 12.650s
# Phoneme: NG, Time: 12.650s - 12.750s
# Phoneme: Z, Time: 12.750s - 12.790s
# Phoneme: W, Time: 12.850s - 12.870s
# Phoneme: ER, Time: 12.870s - 12.950s
# Phoneme: M, Time: 13.030s - 13.070s
# Phoneme: EH, Time: 13.070s - 13.150s
# Phoneme: M, Time: 13.150s - 13.170s
# Phoneme: ER, Time: 13.170s - 13.271s
# Phoneme: AH, Time: 13.271s - 13.351s
# Phoneme: B, Time: 13.351s - 13.371s
# Phoneme: AH, Time: 13.371s - 13.471s
# Phoneme: L, Time: 13.471s - 13.491s

# %%
# Play the first 10 phonemes
for i in range(10):
    display_segment(phoneme_segments, i, waveform, sample_rate)
# Out:
# B (1401915.25): 0.600 - 0.620 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AH (1258843.84): 0.620 - 0.661 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# T (829433.08): 0.661 - 0.701 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AE (612992.91): 0.781 - 0.841 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# F (541718.73): 0.841 - 0.881 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# T (3204450.00): 0.881 - 0.901 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ER (677875.56): 0.901 - 1.061 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AO (572728.64): 1.161 - 1.301 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# L (3603248.25): 1.301 - 1.321 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# DH (659742.44): 1.381 - 1.401 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Method 3: Montreal Forced Aligner
#
# MFA (https://montreal-forced-aligner.readthedocs.io/en/latest/getting_started.html) is the most popular and widely used forced aligner and includes phoneme alignment. However, it is not a CTC-based algorithm. I include it here as a possible benchmark to test against.

# %%
# MFA must be run in its own conda environment. The command to generate the alignment is:
# "mfa align --clean input/ english_us_arpa english_us_arpa output"
# This creates a textgrid file in the output folder.

# load textgrid file
textgrid_file = 'output/assessment_9.TextGrid'
textgrid = tgt.io.read_textgrid(textgrid_file)
phones = textgrid.get_tier_by_name('phones').intervals

phoneme_segments = []
for phone in phones:
    segment = Segment(re.sub(r'\d', '', phone.text), float(phone.start_time), float(phone.end_time), 1.0)
    phoneme_segments.append(segment)

# phoneme_segments
for phoneme in phoneme_segments:
    print(f"Phoneme: {phoneme.label}, Time: {phoneme.start:.3f}s - {phoneme.end:.3f}s") # note the precision is in hundredths of a second, not milliseconds

save_phonemes_JSON(phoneme_segments, 'output/method_3.json')
# Out:
# Phoneme: B, Time: 0.600s - 0.630s
# Phoneme: AH, Time: 0.630s - 0.660s
# Phoneme: T, Time: 0.660s - 0.690s
# Phoneme: AE, Time: 0.690s - 0.820s
# Phoneme: F, Time: 0.820s - 0.870s
# Phoneme: T, Time: 0.870s - 0.930s
# Phoneme: ER, Time: 0.930s - 1.010s
# Phoneme: AO, Time: 1.010s - 1.270s
# Phoneme: L, Time: 1.270s - 1.350s
# Phoneme: DH, Time: 1.350s - 1.390s
# Phoneme: AE, Time: 1.390s - 1.520s
# Phoneme: T, Time: 1.520s - 1.600s
# Phoneme: K, Time: 1.600s - 1.630s
# Phoneme: AH, Time: 1.630s - 1.660s
# Phoneme: M, Time: 1.660s - 1.740s
# Phoneme: OW, Time: 1.740s - 1.860s
# Phoneme: SH, Time: 1.860s - 1.990s
# Phoneme: AH, Time: 1.990s - 2.060s
# Phoneme: N, Time: 2.060s - 2.200s
# Phoneme: W, Time: 2.830s - 2.920s
# Phoneme: AH, Time: 2.920s - 3.010s
# Phoneme: Z, Time: 3.010s - 3.070s
# Phoneme: IH, Time: 3.070s - 3.110s
# Phoneme: T, Time: 3.110s - 3.140s
# Phoneme: AO, Time: 3.140s - 3.320s
# Phoneme: L, Time: 3.320s - 3.390s
# Phoneme: W, Time: 3.390s - 3.470s
# Phoneme: ER, Time: 3.470s - 3.550s
# Phoneme: TH, Time: 3.550s - 3.700s
# Phoneme: W, Time: 3.700s - 3.760s
# Phoneme: AY, Time: 3.760s - 3.940s
# Phoneme: L, Time: 3.940s - 4.140s
# Phoneme: AE, Time: 5.440s - 5.650s
# Phoneme: B, Time: 5.650s - 5.720s
# Phoneme: S, Time: 5.720s - 5.840s
# Phoneme: AH, Time: 5.840s - 5.910s
# Phoneme: L, Time: 5.910s - 6.100s
# Phoneme: UW, Time: 6.100s - 6.140s
# Phoneme: T, Time: 6.140s - 6.180s
# Phoneme: L, Time: 6.180s - 6.210s
# Phoneme: IY, Time: 6.210s - 6.270s
# Phoneme: Y, Time: 6.270s - 6.390s
# Phoneme: EH, Time: 6.390s - 6.540s
# Phoneme: S, Time: 6.540s - 6.840s
# Phoneme: DH, Time: 7.490s - 7.510s
# Phoneme: AH, Time: 7.510s - 7.550s
# Phoneme: S, Time: 7.550s - 7.700s
# Phoneme: EH, Time: 7.700s - 7.820s
# Phoneme: T, Time: 7.820s - 7.880s
# Phoneme: D, Time: 7.880s - 7.910s
# Phoneme: IH, Time: 7.910s - 7.980s
# Phoneme: Z, Time: 7.980s - 8.060s
# Phoneme: AY, Time: 8.060s - 8.300s
# Phoneme: N, Time: 8.300s - 8.430s
# Phoneme: W, Time: 8.460s - 8.500s
# Phoneme: AH, Time: 8.500s - 8.550s
# Phoneme: Z, Time: 8.550s - 8.680s
# Phoneme: B, Time: 8.680s - 8.760s
# Phoneme: R, Time: 8.760s - 8.860s
# Phoneme: EH, Time: 8.860s - 8.940s
# Phoneme: TH, Time: 8.940s - 9.030s
# Phoneme: T, Time: 9.030s - 9.110s
# Phoneme: EY, Time: 9.110s - 9.210s
# Phoneme: K, Time: 9.210s - 9.290s
# Phoneme: IH, Time: 9.290s - 9.380s
# Phoneme: NG, Time: 9.380s - 9.500s
# Phoneme: DH, Time: 9.790s - 9.810s
# Phoneme: IY, Time: 9.810s - 9.910s
# Phoneme: AE, Time: 9.910s - 10.050s
# Phoneme: K, Time: 10.050s - 10.110s
# Phoneme: T, Time: 10.110s - 10.170s
# Phoneme: ER, Time: 10.170s - 10.270s
# Phoneme: Z, Time: 10.270s - 10.360s
# Phoneme: W, Time: 10.360s - 10.500s
# Phoneme: ER, Time: 10.500s - 10.710s
# Phoneme: IH, Time: 10.740s - 10.820s
# Phoneme: N, Time: 10.820s - 10.920s
# Phoneme: K, Time: 10.920s - 11.100s
# Phoneme: R, Time: 11.100s - 11.130s
# Phoneme: EH, Time: 11.130s - 11.190s
# Phoneme: D, Time: 11.190s - 11.230s
# Phoneme: AH, Time: 11.230s - 11.300s
# Phoneme: B, Time: 11.300s - 11.380s
# Phoneme: AH, Time: 11.380s - 11.400s
# Phoneme: L, Time: 11.400s - 11.550s
# Phoneme: AE, Time: 12.040s - 12.160s
# Phoneme: N, Time: 12.160s - 12.220s
# Phoneme: D, Time: 12.220s - 12.250s
# Phoneme: DH, Time: 12.250s - 12.270s
# Phoneme: AH, Time: 12.270s - 12.300s
# Phoneme: S, Time: 12.300s - 12.450s
# Phoneme: AO, Time: 12.450s - 12.630s
# Phoneme: NG, Time: 12.630s - 12.720s
# Phoneme: Z, Time: 12.720s - 12.790s
# Phoneme: W, Time: 12.790s - 12.860s
# Phoneme: ER, Time: 12.860s - 12.940s
# Phoneme: M, Time: 12.940s - 13.030s
# Phoneme: EH, Time: 13.030s - 13.120s
# Phoneme: M, Time: 13.120s - 13.210s
# Phoneme: ER, Time: 13.210s - 13.260s
# Phoneme: AH, Time: 13.260s - 13.290s
# Phoneme: B, Time: 13.290s - 13.380s
# Phoneme: AH, Time: 13.380s - 13.400s
# Phoneme: L, Time: 13.400s - 13.560s

# %%
# Play the first 10 phonemes

for i in range(10):
    display_segment(phoneme_segments, i, waveform, sample_rate)
# Out:
# B (1.00): 0.600 - 0.630 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AH (1.00): 0.630 - 0.660 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# T (1.00): 0.660 - 0.690 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AE (1.00): 0.690 - 0.820 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# F (1.00): 0.820 - 0.870 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# T (1.00): 0.870 - 0.930 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ER (1.00): 0.930 - 1.010 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# AO (1.00): 1.010 - 1.270 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# L (1.00): 1.270 - 1.350 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# DH (1.00): 1.350 - 1.390 sec
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Testing
#
# These methods should be tested on the LJSpeech dataset using the alignment loss metric.
# Finally, the best CTC-based method may be the 960-hr wav2vec2 model fine tuned on the LJSpeech dataset with Arpabet phonemes, but fine-tuning wav2vec2 is beyond the scope of this assignment.
